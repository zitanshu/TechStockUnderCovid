# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pylab as plt

# %% [markdown]
# ### Data Processing

# %%
### Data Processing

# %%
AAPL = pd.read_csv("./data/AAPL.csv")
AAPL['Date'] = pd.to_datetime(AAPL['Date'])
AAPL.set_index('Date', inplace = True)
AAPL_before = AAPL.iloc[:252]['Adj Close']
AAPL_after = AAPL.iloc[252:]['Adj Close']
AAPL_after
# Out:
# Date
# 2020-02-03     75.938805
# 2020-02-04     78.445831
# 2020-02-05     79.085503
# 2020-02-06     80.010574
# 2020-02-07     78.923004
#                  ...
# 2022-01-25    159.576691
# 2022-01-26    159.486801
# 2022-01-27    159.017410
# 2022-01-28    170.113266
# 2022-01-31    174.557602
# Name: Adj Close, Length: 504, dtype: float64

# %%
# MSFT = pd.read_csv("/content/drive/Shared drives/DSCI560 Project/data/MSFT.csv")
MSFT = pd.read_csv("./data/MSFT.csv")
MSFT['Date'] = pd.to_datetime(MSFT['Date'])
MSFT.set_index('Date', inplace = True)
MSFT_before = MSFT.iloc[:252]['Adj Close']
MSFT_after = MSFT.iloc[252:]['Adj Close']
MSFT_after
# Out:
# Date
# 2020-02-03    170.764618
# 2020-02-04    176.385590
# 2020-02-05    176.170151
# 2020-02-06    179.822830
# 2020-02-07    180.077438
#                  ...
# 2022-01-25    287.894714
# 2022-01-26    296.097748
# 2022-01-27    299.221283
# 2022-01-28    307.623932
# 2022-01-31    310.338318
# Name: Adj Close, Length: 504, dtype: float64

# %%
# GOOG = pd.read_csv("/content/drive/Shared drives/DSCI560 Project/data/GOOG.csv")
GOOG = pd.read_csv("./data/GOOG.csv")
GOOG['Date'] = pd.to_datetime(GOOG['Date'])
GOOG.set_index('Date', inplace = True)
GOOG_before = GOOG.iloc[:252]['Adj Close']
GOOG_after = GOOG.iloc[252:]['Adj Close']
GOOG_after
# Out:
# Date
# 2020-02-03    1485.939941
# 2020-02-04    1447.069946
# 2020-02-05    1448.229980
# 2020-02-06    1476.229980
# 2020-02-07    1479.229980
#                  ...
# 2022-01-25    2534.709961
# 2022-01-26    2584.800049
# 2022-01-27    2582.419922
# 2022-01-28    2665.790039
# 2022-01-31    2713.969971
# Name: Adj Close, Length: 504, dtype: float64

# %%
# AMZN = pd.read_csv("/content/drive/Shared drives/DSCI560 Project/data/AMZN.csv")
AMZN = pd.read_csv("./data/AMZN.csv")
AMZN['Date'] = pd.to_datetime(AMZN['Date'])
AMZN.set_index('Date', inplace = True)
AMZN_before = AMZN.iloc[:252]['Adj Close']
AMZN_after = AMZN.iloc[252:]['Adj Close']
AMZN_after
# Out:
# Date
# 2020-02-03    2004.199951
# 2020-02-04    2049.669922
# 2020-02-05    2039.869995
# 2020-02-06    2050.229980
# 2020-02-07    2079.280029
#                  ...
# 2022-01-25    2799.719971
# 2022-01-26    2777.449951
# 2022-01-27    2792.750000
# 2022-01-28    2879.560059
# 2022-01-31    2991.469971
# Name: Adj Close, Length: 504, dtype: float64

# %%
# TSLA = pd.read_csv("/content/drive/Shared drives/DSCI560 Project/data/TSLA.csv")
TSLA = pd.read_csv("./data/TSLA.csv")
TSLA['Date'] = pd.to_datetime(TSLA['Date'])
TSLA.set_index('Date', inplace = True)
TSLA_before = TSLA.iloc[:252]['Adj Close']
TSLA_after = TSLA.iloc[252:]['Adj Close']
TSLA_after
# Out:
# Date
# 2020-02-03    156.000000
# 2020-02-04    177.412003
# 2020-02-05    146.940002
# 2020-02-06    149.792007
# 2020-02-07    149.613998
#                  ...
# 2022-01-25    918.400024
# 2022-01-26    937.409973
# 2022-01-27    829.099976
# 2022-01-28    846.349976
# 2022-01-31    936.719971
# Name: Adj Close, Length: 504, dtype: float64

# %%
# FB = pd.read_csv("/content/drive/Shared drives/DSCI560 Project/data/FB.csv")
FB = pd.read_csv('./data/FB.csv')
FB['Date'] = pd.to_datetime(FB['Date'])
FB.set_index('Date', inplace = True)
FB_before = FB.iloc[:252]['Adj Close']
FB_after = FB.iloc[252:]['Adj Close']
FB_after
# Out:
# Date
# 2020-02-03    204.190002
# 2020-02-04    209.830002
# 2020-02-05    210.110001
# 2020-02-06    210.850006
# 2020-02-07    212.330002
#                  ...
# 2022-01-25    300.149994
# 2022-01-26    294.630005
# 2022-01-27    294.640015
# 2022-01-28    301.709991
# 2022-01-31    313.260010
# Name: Adj Close, Length: 504, dtype: float64

# %%
# NVDA = pd.read_csv("/content/drive/Shared drives/DSCI560 Project/data/NVDA.csv")
NVDA = pd.read_csv("./data/NVDA.csv")
NVDA['Date'] = pd.to_datetime(NVDA['Date'])
NVDA.set_index('Date', inplace = True)
NVDA_before = NVDA.iloc[:252]['Adj Close']
NVDA_after = NVDA.iloc[252:]['Adj Close']
NVDA_before
# Out:
# Date
# 2019-02-01    35.950966
# 2019-02-04    37.056343
# 2019-02-05    37.247608
# 2019-02-06    38.005238
# 2019-02-07    36.619164
#                 ...
# 2020-01-27    59.898762
# 2020-01-28    61.836369
# 2020-01-29    61.230392
# 2020-01-30    61.297726
# 2020-01-31    58.958633
# Name: Adj Close, Length: 252, dtype: float64

# %%
# INTC = pd.read_csv("/content/drive/Shared drives/DSCI560 Project/data/INTC.csv")
INTC  =pd.read_csv("./data/INTC.csv")
INTC['Date'] = pd.to_datetime(INTC['Date'])
INTC.set_index('Date', inplace = True)
INTC_before = INTC.iloc[:252]['Adj Close']
INTC_after = INTC.iloc[252:]['Adj Close']
INTC_after
# Out:
# Date
# 2020-02-03    60.805180
# 2020-02-04    61.786819
# 2020-02-05    63.561337
# 2020-02-06    63.637211
# 2020-02-07    62.622276
#                 ...
# 2022-01-25    50.614437
# 2022-01-26    51.299217
# 2022-01-27    47.686737
# 2022-01-28    47.369156
# 2022-01-31    48.450916
# Name: Adj Close, Length: 504, dtype: float64

# %% [markdown]
# ### Time Series Analysis - VAR
#
# https://www.machinelearningplus.com/time-series/vector-autoregression-examples-python/

# %% [markdown]
# #### Statistical Testing - ADF function

# %%
# from statsmodels.tsa.arima.model import ARIMA
from matplotlib import pyplot

from statsmodels.tsa.stattools import adfuller
#Dickey-Fuller test for stationariality 
def DF_test(data, name):
    #moving mean and std
    move_m =data.rolling(12).mean()
    move_std = data.rolling(12).std()
#     plt.plot(data, color = 'black', label = 'data_line')
#     plt.plot(move_m, color = 'red', label = 'moving average')
#     plt.plot(move_std, color = 'green', label = 'moving std')
#     plt.title("Mvoing Average & Std")
    
    test_res = adfuller(data, autolag = 'AIC')
    print(name)
    print('Test statistic:', test_res[0])
    print('P-value:', test_res[1])
    print('Number of lags used:', test_res[2])
    print('Number of observation used:', test_res[3])
    print('Critical values:', test_res[4])

# %% [markdown]
# #### Statistical Testing - Granger's Causality Test Function

# %%
# Granger’s Causality Test
from statsmodels.tsa.stattools import grangercausalitytests
maxlag=12
test = 'ssr_chi2test'
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

# %% [markdown]
# #### Statistical Testing - Cointegration Test Function

# %%
# cointegration_test
from statsmodels.tsa.vector_ar.vecm import coint_johansen

def cointegration_test(df, alpha=0.1): 
    """Perform Johanson's Cointegration Test and Report Summary"""
    out = coint_johansen(df,-1,5)
    d = {'0.9':0, '0.95':1, '0.99':2}
    traces = out.lr1
    cvts = out.cvt[:, d[str(1-alpha)]]
#     print(out.cvt)
    def adjust(val, length= 6): return str(val).ljust(length)

    # Summary
    print('Name   ::  Test Stat > C(90%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

# %% [markdown]
# #### Before - VAR

# %% [markdown]
# #### merge the companies' stocks datatsets together -> then fit the models (Vector Auto Regression (VAR))

# %%
# Import Statsmodels
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic

#all stock before dataframe merge
all_stock_before = pd.DataFrame()
all_stock_before['AAPL'] = AAPL_before
all_stock_before['MSFT'] = MSFT_before
all_stock_before['GOOG'] = GOOG_before
all_stock_before['AMZN'] = AMZN_before
all_stock_before['TSLA'] = TSLA_before
all_stock_before['FB'] = FB_before
all_stock_before['NVDA'] = NVDA_before
all_stock_before['INTC'] = INTC_before
all_stock_before
# Out:
#                  AAPL        MSFT         GOOG         AMZN        TSLA  \
# Date
# 2019-02-01  40.362038   99.182549  1110.750000  1626.229980   62.442001
# 2019-02-04  41.508518  102.038948  1132.800049  1633.310059   62.577999
# 2019-02-05  42.218708  103.467148  1145.989990  1658.810059   64.269997
# 2019-02-06  42.233253  102.318794  1115.229980  1640.260010   63.444000
# 2019-02-07  41.433384  101.585396  1098.709961  1614.369995   61.501999
# ...               ...         ...          ...          ...         ...
# 2020-01-27  76.010155  158.915451  1433.900024  1828.339966  111.603996
# 2020-01-28  78.160431  162.029526  1452.560059  1853.250000  113.379997
# 2020-01-29  79.796524  164.556030  1458.630005  1858.000000  116.197998
# 2020-01-30  79.680885  169.197784  1455.839966  1870.680054  128.162003
# 2020-01-31  76.147942  166.700638  1434.229980  2008.719971  130.113998
#
#                     FB       NVDA       INTC
# Date
# ...

# %%
# Plot for stocks before
fig, axes = plt.subplots(nrows=4, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = all_stock_before[all_stock_before.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(all_stock_before.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
# Granger’s Causality Test
print("Granger’s Causality Test for Stock Data Before the Pandemic:")
grangers_causation_matrix(all_stock_before, variables = all_stock_before.columns)
# Out:
# Granger’s Causality Test for Stock Data Before the Pandemic:
#         AAPL_x  MSFT_x  GOOG_x  AMZN_x  TSLA_x    FB_x  NVDA_x  INTC_x
# AAPL_y  1.0000  0.0012  0.0131  0.0229  0.0193  0.0708  0.1459  0.2561
# MSFT_y  0.0038  1.0000  0.0000  0.0335  0.0026  0.1895  0.0863  0.0000
# GOOG_y  0.0008  0.2327  1.0000  0.4420  0.0034  0.2770  0.0000  0.0005
# AMZN_y  0.2912  0.0405  0.0007  1.0000  0.0769  0.2036  0.2907  0.1542
# TSLA_y  0.0038  0.0002  0.1888  0.0204  1.0000  0.1334  0.0574  0.0079
# FB_y    0.0213  0.0033  0.1117  0.5541  0.0409  1.0000  0.0622  0.1647
# NVDA_y  0.1081  0.0012  0.1181  0.0107  0.1225  0.2246  1.0000  0.1659
# INTC_y  0.1178  0.0319  0.1770  0.0384  0.0036  0.4241  0.0291  1.0000

# %%
# Cointegration Test
print("Cointegration Test for Stock Data Before the Pandemic:")
cointegration_test(all_stock_before)
# Out:
# Cointegration Test for Stock Data Before the Pandemic:
# Name   ::  Test Stat > C(90%)    =>   Signif
#  ----------------------------------------
# AAPL   ::  166.39    > 137.9954  =>   True
# MSFT   ::  122.72    > 106.7351  =>   True
# GOOG   ::  85.7      > 79.5329   =>   True
# AMZN   ::  57.68     > 56.2839   =>   True
# TSLA   ::  36.9      > 37.0339   =>   False
# FB     ::  21.64     > 21.7781   =>   False
# NVDA   ::  10.96     > 10.4741   =>   True
# INTC   ::  1.03      > 2.9762    =>   False

# %%
#train test split
num_obs = 10 # predict for next 10 days
all_stock_before_train, all_stock_before_test = all_stock_before[0:-num_obs], all_stock_before[-num_obs:]

# Check size
print(all_stock_before_train.shape) 
print(all_stock_before_test.shape)
# Out:
# (242, 8)
# (10, 8)

# %%
# ADF Test on each column to check sataionalities - round 1
for name, column in all_stock_before_train.iteritems():
    DF_test(column, name=column.name)
    print('\n')

#all variable are non-stationary, take 1st difference, then re-run ADF test
all_stock_before_differenced = all_stock_before_train.diff().dropna()
# all_stock_before_differenced = all_stock_before_differenced.diff().dropna()
print('-'*100)
for name, column in all_stock_before_differenced.iteritems():
    DF_test(column, name=column.name)
    print('\n')
# Out:
# AAPL
# Test statistic: 1.3804124687808192
# P-value: 0.9970233166511903
# Number of lags used: 0
# Number of observation used: 241
# Critical values: {'1%': -3.4577787098622674, '5%': -2.873608704758507, '10%': -2.573201765981991}
#
#
# MSFT
# Test statistic: -0.26213268223320674
# P-value: 0.9306988857434649
# Number of lags used: 2
# Number of observation used: 239
# Critical values: {'1%': -3.458010773719797, '5%': -2.8737103617125186, '10%': -2.5732559963936206}
#
#
# GOOG
# Test statistic: 0.37460842289569535
# P-value: 0.9805201487232917
# Number of lags used: 11
# Number of observation used: 230
# Critical values: {'1%': -3.459105583381277, '5%': -2.8741898504150574, '10%': -2.5735117958412097}
#
#
# AMZN
# Test statistic: -2.3329989812070906
# P-value: 0.1615458649643503
# Number of lags used: 0
# Number of observation used: 241
# Critical values: {'1%': -3.4577787098622674, '5%': -2.873608704758507, '10%': -2.573201765981991}
#
#
# TSLA
# Test statistic: 1.9931557326936546
# ...

# %% [markdown]
# All p-value < 0.05 after first difference, ready to move on

# %%
#VAR model lag selection and training
model_before = VAR(all_stock_before_differenced)
AIC = []
BIC =  []
FPE = []
HQIC = []
for i in [1,2,3,4,5,6,7,8,9]:
    result = model_before.fit(i)
    AIC.append(result.aic)
    BIC.append(result.bic)
    FPE.append(result.fpe)
    HQIC.append(result.hqic)
#     print('Lag Order =', i)
#     print('AIC : ', result.aic)
#     print('BIC : ', result.bic)
#     print('FPE : ', result.fpe)
#     print('HQIC: ', result.hqic, '\n')
    
x_value = [1,2,3,4,5,6,7,8,9]
plt.plot(x_value, AIC, color = 'black', label = 'aic')
plt.plot(x_value, BIC, color = 'red', label = 'bic')
# plt.plot(FPE, color = 'green', label = 'fpe')
plt.plot(x_value, HQIC, color = 'blue', label = 'hqic')
plt.legend(loc="upper left")
plt.title("Lag Selection for Model with Stock Data Before the Pandemic")
# print("Lag Selection for Model with Stock Data Before the Pandemic: ")


x = model_before.select_order(maxlags=12)
x.summary()
# Out:
# C:\Users\yyh11\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
#use lag 1 as selected model to fit data
model_before_fitted = model_before.fit(1)
model_before_fitted.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 31, Mar, 2022
# Time:                     16:22:10
# --------------------------------------------------------------------
# No. of Equations:         8.00000    BIC:                    12.2008
# Nobs:                     240.000    HQIC:                   11.5773
# Log likelihood:          -3991.15    FPE:                    70041.8
# AIC:                      11.1566    Det(Omega_mle):         52173.8
# --------------------------------------------------------------------
# Results for equation AAPL
# ...
#              coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------
# const           0.166417         0.050497            3.296           0.001
# L1.AAPL        -0.011543         0.092285           -0.125           0.900
# ...

# %%
#check for residuals
from statsmodels.stats.stattools import durbin_watson
out = durbin_watson(model_before_fitted.resid)

for col, val in zip(all_stock_before.columns, out):
    print(col, ':', round(val, 2))
# Out:
# AAPL : 2.02
# MSFT : 2.0
# GOOG : 1.98
# AMZN : 1.97
# TSLA : 2.01
# FB : 2.0
# NVDA : 2.02
# INTC : 1.99

# %%
# Forecasting
# Get the lag order
lag_order_before = model_before_fitted.k_ar
# print(lag_order_before) 

# Input data for forecasting
forecast_before_input = all_stock_before_differenced.values[-lag_order_before:]
forecast_before_input

# Forecast - this is the result in terms of 1st differencing
fc_before = model_before_fitted.forecast(y=forecast_before_input, steps=num_obs)
all_stock_before_forecast = pd.DataFrame(fc_before, index=all_stock_before.index[-num_obs:], columns=all_stock_before.columns + '_1diff')
all_stock_before_forecast
# Out:
#             AAPL_1diff  MSFT_1diff  GOOG_1diff  AMZN_1diff  TSLA_1diff  \
# Date
# 2020-01-17    0.024160    0.074516    2.423114   -2.338716   -0.199301
# 2020-01-21    0.121406    0.267421    1.724702    0.281444    0.137011
# 2020-01-22    0.144674    0.254713    1.255694    0.749556    0.160497
# 2020-01-23    0.149008    0.252770    1.330796    0.990111    0.162183
# 2020-01-24    0.150265    0.252320    1.347332    1.021260    0.164340
# 2020-01-27    0.150484    0.252482    1.349647    1.030616    0.164952
# 2020-01-28    0.150537    0.252470    1.350299    1.032450    0.164964
# 2020-01-29    0.150551    0.252481    1.350749    1.033293    0.164957
# 2020-01-30    0.150553    0.252480    1.350882    1.033435    0.164954
# 2020-01-31    0.150553    0.252481    1.350915    1.033473    0.164953
#
#             FB_1diff  NVDA_1diff  INTC_1diff
# Date
# 2020-01-17 -0.413990   -0.144348   -0.142472
# 2020-01-21  0.215632    0.105211    0.028564
# ...

# %%
#transformation invertion back to original scale
def invert_transformation(df_train, df_forecast, second_diff=False):
    """Revert back the differencing to get the forecast to original scale."""
    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:        
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = df_train[col].iloc[-1] + df_fc[str(col)+'_1diff'].cumsum()
    return df_fc
all_stock_before_results = invert_transformation(all_stock_before_train, all_stock_before_forecast)        
all_stock_before_results
# Out:
#             AAPL_1diff  MSFT_1diff  GOOG_1diff  AMZN_1diff  TSLA_1diff  \
# Date
# 2020-01-17    0.024160    0.074516    2.423114   -2.338716   -0.199301
# 2020-01-21    0.121406    0.267421    1.724702    0.281444    0.137011
# 2020-01-22    0.144674    0.254713    1.255694    0.749556    0.160497
# 2020-01-23    0.149008    0.252770    1.330796    0.990111    0.162183
# 2020-01-24    0.150265    0.252320    1.347332    1.021260    0.164340
# 2020-01-27    0.150484    0.252482    1.349647    1.030616    0.164952
# 2020-01-28    0.150537    0.252470    1.350299    1.032450    0.164964
# 2020-01-29    0.150551    0.252481    1.350749    1.033293    0.164957
# 2020-01-30    0.150553    0.252480    1.350882    1.033435    0.164954
# 2020-01-31    0.150553    0.252481    1.350915    1.033473    0.164953
#
#             FB_1diff  NVDA_1diff  INTC_1diff  AAPL_forecast  MSFT_forecast  \
# Date
# 2020-01-17 -0.413990   -0.144348   -0.142472      77.581831     162.799324
# ...

# %%
#plot for forecast result and actual result
print("Forecast Results vs. Actuals with Stock Data Before the Pandemic:")
fig, axes = plt.subplots(nrows=int(len(all_stock_before.columns)/2), ncols=2, dpi=150, figsize=(10,10))
for i, (col,ax) in enumerate(zip(all_stock_before.columns, axes.flatten())):
    all_stock_before_results[col+'_forecast'].plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    all_stock_before_test[col][-num_obs:].plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();
# Out:
# Forecast Results vs. Actuals with Stock Data Before the Pandemic:

# %%
# evaluation
from statsmodels.tsa.stattools import acf
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'corr':corr, 'minmax':minmax})

res_before = []
name_list = list(all_stock_before.columns)
for name in name_list:
#     print('Forecast Accuracy of: {}'.format(name))
    accuracy_prod = forecast_accuracy(all_stock_before_results[name+'_forecast'].values, all_stock_before_test[name])
#     print(accuracy_prod)
    res_before.append(accuracy_prod)
#     for k, v in accuracy_prod.items():
#         print(k, ': ', round(v,4))
#     print('\n')
print("Evaluation of Model Trained with Stock Data Before the Pandemic:")
res_before = pd.DataFrame.from_dict(res_before, orient='columns')
res_before['Company'] = list(all_stock_before.columns)
res_before = res_before.set_index('Company')
res_before
# Out:
# Evaluation of Model Trained with Stock Data Before the Pandemic:
# <ipython-input-26-af01fb16d32a>:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   actual[:,None]]), axis=1)
# <ipython-input-26-af01fb16d32a>:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   actual[:,None]]), axis=1)
#              mape         me        mae       mpe       rmse      corr  \
# Company
# AAPL     0.012264   0.115851   0.949590  0.001719   1.278333 -0.044713
# MSFT     0.010962   0.427910   1.789755  0.002851   2.457051  0.487785
# GOOG     0.013842  -3.480757  20.281210 -0.002176  22.758129 -0.798732
# AMZN     0.015724  -1.630675  30.132483 -0.000303  45.315706  0.343042
# ...

# %% [markdown]
# #### After - VAR

# %%
#all stock before dataframe merge
all_stock_after = pd.DataFrame()
all_stock_after['AAPL'] = AAPL_after
all_stock_after['MSFT'] = MSFT_after
all_stock_after['GOOG'] = GOOG_after
all_stock_after['AMZN'] = AMZN_after
all_stock_after['TSLA'] = TSLA_after
all_stock_after['FB'] = FB_after
all_stock_after['NVDA'] = NVDA_after
all_stock_after['INTC'] = INTC_after
all_stock_after
# Out:
#                   AAPL        MSFT         GOOG         AMZN        TSLA  \
# Date
# 2020-02-03   75.938805  170.764618  1485.939941  2004.199951  156.000000
# 2020-02-04   78.445831  176.385590  1447.069946  2049.669922  177.412003
# 2020-02-05   79.085503  176.170151  1448.229980  2039.869995  146.940002
# 2020-02-06   80.010574  179.822830  1476.229980  2050.229980  149.792007
# 2020-02-07   78.923004  180.077438  1479.229980  2079.280029  149.613998
# ...                ...         ...          ...          ...         ...
# 2022-01-25  159.576691  287.894714  2534.709961  2799.719971  918.400024
# 2022-01-26  159.486801  296.097748  2584.800049  2777.449951  937.409973
# 2022-01-27  159.017410  299.221283  2582.419922  2792.750000  829.099976
# 2022-01-28  170.113266  307.623932  2665.790039  2879.560059  846.349976
# 2022-01-31  174.557602  310.338318  2713.969971  2991.469971  936.719971
#
#                     FB        NVDA       INTC
# Date
# ...

# %%
# Plot for stocks after
fig, axes = plt.subplots(nrows=4, ncols=2, dpi=120, figsize=(12,10))
for i, ax in enumerate(axes.flatten()):
    data = all_stock_after[all_stock_after.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(all_stock_after.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
# Grangers Causality Test 
print("Granger’s Causality Test for Stock Data During the Pandemic:")
grangers_causation_matrix(all_stock_after, variables = all_stock_after.columns)
# Out:
# Granger’s Causality Test for Stock Data During the Pandemic:
#         AAPL_x  MSFT_x  GOOG_x  AMZN_x  TSLA_x    FB_x  NVDA_x  INTC_x
# AAPL_y  1.0000  0.0001  0.0078  0.2866  0.3448  0.0056  0.0394  0.0001
# MSFT_y  0.0412  1.0000  0.1279  0.0775  0.4663  0.0551  0.1002  0.0002
# GOOG_y  0.2546  0.0580  1.0000  0.3390  0.5148  0.4138  0.0148  0.0083
# AMZN_y  0.4565  0.0058  0.3710  1.0000  0.2414  0.3384  0.3431  0.0311
# TSLA_y  0.0876  0.0832  0.1338  0.1260  1.0000  0.1498  0.0906  0.0140
# FB_y    0.5403  0.0002  0.0103  0.0771  0.2956  1.0000  0.6435  0.0009
# NVDA_y  0.0233  0.0001  0.0156  0.0180  0.1426  0.1491  1.0000  0.0198
# INTC_y  0.1355  0.0427  0.6975  0.3465  0.8601  0.3665  0.4291  1.0000

# %%
# Cointegration Test
print("Cointegration Test for Stock Data During the Pandemic:")
cointegration_test(all_stock_after)
# Out:
# Cointegration Test for Stock Data During the Pandemic:
# Name   ::  Test Stat > C(90%)    =>   Signif
#  ----------------------------------------
# AAPL   ::  164.57    > 137.9954  =>   True
# MSFT   ::  107.26    > 106.7351  =>   True
# GOOG   ::  70.89     > 79.5329   =>   False
# AMZN   ::  46.15     > 56.2839   =>   False
# TSLA   ::  29.58     > 37.0339   =>   False
# FB     ::  15.49     > 21.7781   =>   False
# NVDA   ::  6.43      > 10.4741   =>   False
# INTC   ::  0.57      > 2.9762    =>   False

# %%
#train test split for all_stock_after
num_obs_after = 10 # predict for next 10 days
all_stock_after_train, all_stock_after_test = all_stock_after[0:-num_obs_after], all_stock_after[-num_obs_after:]


# Check size
print(all_stock_after_train.shape) 
print(all_stock_after_test.shape)
# Out:
# (494, 8)
# (10, 8)

# %%
# ADF Test on each column to check sataionalities for all_stock_after - round 1
for name, column in all_stock_after_train.iteritems():
    DF_test(column, name=column.name)
    print('\n')

#all variable are non-stationary, take 1st difference, then re-run ADF test
all_stock_after_differenced = all_stock_after_train.diff().dropna()
# all_stock_after_differenced = all_stock_after_differenced.diff().dropna()

for name, column in all_stock_after_differenced.iteritems():
    DF_test(column, name=column.name)
    print('\n')
# Out:
# AAPL
# Test statistic: -0.4799194510940182
# P-value: 0.895875871665758
# Number of lags used: 1
# Number of observation used: 492
# Critical values: {'1%': -3.4437112724287253, '5%': -2.8674324209387345, '10%': -2.569908433637385}
#
#
# MSFT
# Test statistic: -0.5984217918568951
# P-value: 0.8713382386234054
# Number of lags used: 9
# Number of observation used: 484
# Critical values: {'1%': -3.4439333076538854, '5%': -2.8675301216074414, '10%': -2.56996050355167}
#
#
# GOOG
# Test statistic: -0.3015933139580943
# P-value: 0.925278367940137
# Number of lags used: 1
# Number of observation used: 492
# Critical values: {'1%': -3.4437112724287253, '5%': -2.8674324209387345, '10%': -2.569908433637385}
#
#
# AMZN
# Test statistic: -2.181328325825993
# P-value: 0.21309185206489045
# Number of lags used: 3
# Number of observation used: 490
# Critical values: {'1%': -3.4437660979098843, '5%': -2.8674565460819896, '10%': -2.569921291128696}
#
#
# TSLA
# Test statistic: -0.714322721260017
# ...

# %% [markdown]
# All p-value < 0.05 after 1st differencing, ready to move on.

# %%
#VAR model lag selection and training
model_after = VAR(all_stock_after_differenced)
AIC_after = []
BIC_after =  []
FPE_after = []
HQIC_after = []
for i in [1,2,3,4,5,6,7,8,9]:
    result = model_after.fit(i)
    AIC_after.append(result.aic)
    BIC_after.append(result.bic)
    FPE_after.append(result.fpe)
    HQIC_after.append(result.hqic)



x_value = [1,2,3,4,5,6,7,8,9]
plt.plot(x_value, AIC_after, color = 'black', label = 'aic')
plt.plot(x_value, BIC_after, color = 'red', label = 'bic')
# plt.plot(FPE, color = 'green', label = 'fpe')
plt.plot(x_value, HQIC_after, color = 'blue', label = 'hqic')
plt.legend(loc="upper left")
plt.title("Lag Selection for Model with Stock Data During the Pandemic")

a = model_after.select_order(maxlags=12)
a.summary()
# Out:
# C:\Users\yyh11\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
#use lag 1 as selected model to fit data
model_after_fitted = model_after.fit(1)
model_after_fitted.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 31, Mar, 2022
# Time:                     16:22:18
# --------------------------------------------------------------------
# No. of Equations:         8.00000    BIC:                    30.2746
# Nobs:                     492.000    HQIC:                   29.9015
# Log likelihood:          -12809.4    FPE:                7.60824e+12
# AIC:                      29.6602    Det(Omega_mle):     6.58118e+12
# --------------------------------------------------------------------
# Results for equation AAPL
# ...
#              coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------
# const           0.183250         0.109552            1.673           0.094
# L1.AAPL        -0.044330         0.071786           -0.618           0.537
# ...

# %%
#check for residuals
from statsmodels.stats.stattools import durbin_watson
out = durbin_watson(model_after_fitted.resid)

for col, val in zip(all_stock_after.columns, out):
    print(col, ':', round(val, 2))
# Out:
# AAPL : 1.98
# MSFT : 1.96
# GOOG : 1.97
# AMZN : 1.98
# TSLA : 1.99
# FB : 1.98
# NVDA : 2.01
# INTC : 1.99

# %%
# Forecasting
# Get the lag order
lag_order_after = model_after_fitted.k_ar
# print(lag_order_before) 

# Input data for forecasting
forecast_after_input = all_stock_after_differenced.values[-lag_order_after:]
forecast_after_input

# Forecast - this is the result in terms of 1st differencing
fc_after = model_after_fitted.forecast(y=forecast_after_input, steps=num_obs_after)
all_stock_after_forecast = pd.DataFrame(fc_after, index=all_stock_after.index[-num_obs_after:], columns=all_stock_after.columns + '_1diff')
all_stock_after_forecast
# Out:
#             AAPL_1diff  MSFT_1diff  GOOG_1diff  AMZN_1diff  TSLA_1diff  \
# Date
# 2022-01-18   -0.181069   -0.667777   -3.588888   -3.823450    4.231734
# 2022-01-19    0.351742    0.604610    4.702783    3.856807    2.177603
# 2022-01-20    0.152938    0.165910    2.231967    1.933905    1.654486
# 2022-01-21    0.204580    0.301556    2.894174    2.597313    1.799226
# 2022-01-24    0.188403    0.259954    2.690108    2.387463    1.768756
# 2022-01-25    0.193608    0.273041    2.755318    2.453408    1.779700
# 2022-01-26    0.191978    0.268924    2.734817    2.432546    1.776060
# 2022-01-27    0.192489    0.270217    2.741259    2.439122    1.777192
# 2022-01-28    0.192329    0.269811    2.739231    2.437054    1.776837
# 2022-01-31    0.192379    0.269939    2.739869    2.437704    1.776949
#
#             FB_1diff  NVDA_1diff  INTC_1diff
# Date
# 2022-01-18 -1.413637   -0.095385   -0.402227
# 2022-01-19  0.500526    0.757732    0.105944
# ...

# %%
#transformation invertion back to original scale
all_stock_after_results = invert_transformation(all_stock_after_train, all_stock_after_forecast)        
all_stock_after_results
# Out:
#             AAPL_1diff  MSFT_1diff  GOOG_1diff  AMZN_1diff  TSLA_1diff  \
# Date
# 2022-01-18   -0.181069   -0.667777   -3.588888   -3.823450    4.231734
# 2022-01-19    0.351742    0.604610    4.702783    3.856807    2.177603
# 2022-01-20    0.152938    0.165910    2.231967    1.933905    1.654486
# 2022-01-21    0.204580    0.301556    2.894174    2.597313    1.799226
# 2022-01-24    0.188403    0.259954    2.690108    2.387463    1.768756
# 2022-01-25    0.193608    0.273041    2.755318    2.453408    1.779700
# 2022-01-26    0.191978    0.268924    2.734817    2.432546    1.776060
# 2022-01-27    0.192489    0.270217    2.741259    2.439122    1.777192
# 2022-01-28    0.192329    0.269811    2.739231    2.437054    1.776837
# 2022-01-31    0.192379    0.269939    2.739869    2.437704    1.776949
#
#             FB_1diff  NVDA_1diff  INTC_1diff  AAPL_forecast  MSFT_forecast  \
# Date
# 2022-01-18 -1.413637   -0.095385   -0.402227     172.668723     308.892160
# ...

# %%
#plot for forecast result and actual result
print("Forecast Results vs. Actuals with Stock Data During the Pandemic:")

fig, axes = plt.subplots(nrows=int(len(all_stock_after.columns)/2), ncols=2, dpi=150, figsize=(10,10))
for i, (col,ax) in enumerate(zip(all_stock_after.columns, axes.flatten())):
    all_stock_after_results[col+'_forecast'].plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    all_stock_after_test[col][-num_obs_after:].plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();
# Out:
# Forecast Results vs. Actuals with Stock Data During the Pandemic:

# %%
# evaluation
from statsmodels.tsa.stattools import acf
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'corr':corr, 'minmax':minmax})

# name_list = list(all_stock_after.columns)
# for name in name_list:
#     print('Forecast Accuracy of: {}'.format(name))
#     accuracy_prod = forecast_accuracy(all_stock_after_results[name+'_forecast'].values, all_stock_after_test[name])
#     for k, v in accuracy_prod.items():
#         print(k, ': ', round(v,4))
#     print('\n')
    
res_after = []
name_list = list(all_stock_after.columns)
for name in name_list:
#     print('Forecast Accuracy of: {}'.format(name))
    accuracy_prod = forecast_accuracy(all_stock_after_results[name+'_forecast'].values, all_stock_after_test[name])
#     print(accuracy_prod)
    res_after.append(accuracy_prod)
#     for k, v in accuracy_prod.items():
#         print(k, ': ', round(v,4))
#     print('\n')
print("Evaluation of Model Trained with Stock Data During the Pandemic:")
res_after = pd.DataFrame.from_dict(res_after, orient='columns')
res_after['Company'] = list(all_stock_after.columns)
res_after = res_after.set_index('Company')
res_after
# Out:
# Evaluation of Model Trained with Stock Data During the Pandemic:
# <ipython-input-39-d3271c6009ad>:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   actual[:,None]]), axis=1)
# <ipython-input-39-d3271c6009ad>:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   actual[:,None]]), axis=1)
#              mape          me         mae       mpe        rmse      corr  \
# Company
# AAPL     0.055824    9.025680    9.031367  0.055792   10.329025  0.102701
# MSFT     0.035567   10.536128   10.536128  0.035567   12.125435  0.248223
# GOOG     0.063477  165.919958  165.919958  0.063477  178.498634 -0.290498
# AMZN     0.111049  318.631036  318.631036  0.111049  348.105217 -0.641620
# ...

# %% [markdown]
# ### Time Series - ARIMA
#
# https://medium.com/@derejeabera/stock-price-prediction-using-arima-model-251ddb4ee52a

# %%
# ADF Test on each column to check sataionalities - round 1
for name, column in all_stock_before_train.iteritems():
    DF_test(column, name=column.name)
    print('\n')

print('1st difference')
#all variable are non-stationary, take 1st difference, then re-run ADF test
all_stock_before_differenced = all_stock_before_train.diff().dropna()
# all_stock_before_differenced = all_stock_before_differenced.diff().dropna()

for name, column in all_stock_before_differenced.iteritems():
    DF_test(column, name=column.name)
    print('\n')
# Out:
# AAPL
# Test statistic: 1.3804124687808192
# P-value: 0.9970233166511903
# Number of lags used: 0
# Number of observation used: 241
# Critical values: {'1%': -3.4577787098622674, '5%': -2.873608704758507, '10%': -2.573201765981991}
#
#
# MSFT
# Test statistic: -0.26213268223320674
# P-value: 0.9306988857434649
# Number of lags used: 2
# Number of observation used: 239
# Critical values: {'1%': -3.458010773719797, '5%': -2.8737103617125186, '10%': -2.5732559963936206}
#
#
# GOOG
# Test statistic: 0.37460842289569535
# P-value: 0.9805201487232917
# Number of lags used: 11
# Number of observation used: 230
# Critical values: {'1%': -3.459105583381277, '5%': -2.8741898504150574, '10%': -2.5735117958412097}
#
#
# AMZN
# Test statistic: -2.3329989812070906
# P-value: 0.1615458649643503
# Number of lags used: 0
# Number of observation used: 241
# Critical values: {'1%': -3.4577787098622674, '5%': -2.873608704758507, '10%': -2.573201765981991}
#
#
# TSLA
# Test statistic: 1.9931557326936546
# ...

# %%
# Plot for stocks before
fig, axes = plt.subplots(nrows=4, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = all_stock_before_differenced[all_stock_before_differenced.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(all_stock_before.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout()

# %%
models=[]
import pmdarima as pm
for i, ax in enumerate(axes.flatten()):
    data = all_stock_before_differenced[all_stock_before_differenced.columns[i]]
    print('-'*100)
    print(all_stock_before_differenced.columns[i])
    model =  pm.auto_arima(data,start_p=0,d=1,start_q=0,
          max_p=5,max_d=5,max_q=5, start_P=0,
          D=1, start_Q=0, max_P=5,max_D=5,
          max_Q=5, m=12, seasonal=True,
          error_action='warn',trace=False,
          supress_warnings=True,stepwise=True,
          random_state=20,n_fits=50)
    print(model.summary())
    models.append(model)
# Out:
# ----------------------------------------------------------------------------------------------------
# AAPL
#                                      SARIMAX Results
# ...
# Dep. Variable:                                  y   No. Observations:                  241
# Model:             SARIMAX(2, 1, 1)x(4, 1, 1, 12)   Log Likelihood                -274.429
# Date:                            Thu, 31 Mar 2022   AIC                            566.858
# Time:                                    16:30:33   BIC                            597.723
# Sample:                                         0   HQIC                           579.311
#                                             - 241
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0575      0.072     -0.803      0.422      -0.198       0.083
# ...

# %%
# Forecast
n_periods = 10
for i in range(8):
    model = models[i]
    models[i].plot_diagnostics()

# %%
# ARIMA模型评价
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))
    me = np.mean(forecast - actual)
    mae = np.mean(np.abs(forecast - actual))
    mpe = np.mean((forecast - actual)/actual)
    # rmse = np.mean((forecast - actual)**2)**0.5    # RMSE
    rmse_1 = np.sqrt(sum((forecast - actual) ** 2) / actual.size)
    corr = np.corrcoef(forecast, actual)[0, 1]
    mins = np.amin(np.hstack([forecast[:, None], actual[:, None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:, None], actual[:, None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)
    return ({'mape': mape,
             'me': me,
             'mae': mae,
             'mpe': mpe,
             'rmse': rmse_1,
             'corr': corr,
             'minmax': minmax
             })

# %%
n_periods = 10
fig, axes = plt.subplots(nrows=4, ncols=2, dpi=120, figsize=(10,10))
for i, ax in enumerate(axes.flatten()):
    model = models[i]
    df = all_stock_before_test[all_stock_before_test.columns[i]]

    fc, confint = model.predict(n_periods=n_periods, return_conf_int=True)

    index_of_fc = np.arange(n_periods)
    x0 = all_stock_before[all_stock_before.columns[i]][-1]
    y0 = all_stock_before_test[all_stock_before_test.columns[i]]
   
    # make series for plotting purpose
    fc_series = pd.Series(fc, index=index_of_fc)
    
    y1 = x0+fc_series.cumsum()
    lower_series = pd.Series(confint[:, 0], index=index_of_fc)
    upper_series = pd.Series(confint[:, 1], index=index_of_fc)
    # Plot
    ax.plot(index_of_fc,y0)
    ax.plot(y1, color='darkgreen')

    ax.fill_between(lower_series.index, 
                     x0+lower_series.cumsum(), 
                     x0+upper_series.cumsum(), 
                     color='k', alpha=.15)

    ax.set_title(all_stock_before_test.columns[i])
    ax.legend(['original','predict','lower and upper'])
    
    # model evaluation
    eval_result = forecast_accuracy(y1, np.array(y0))
    print('model evaluation result\n', eval_result)
# Out:
# <ipython-input-48-532768efb9ad>:10: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   mins = np.amin(np.hstack([forecast[:, None], actual[:, None]]), axis=1)
# <ipython-input-48-532768efb9ad>:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   maxs = np.amax(np.hstack([forecast[:, None], actual[:, None]]), axis=1)
# <ipython-input-48-532768efb9ad>:10: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   mins = np.amin(np.hstack([forecast[:, None], actual[:, None]]), axis=1)
# ...

# %%
# ADF Test on each column to check sataionalities - round 1

all_stock_after_train, all_stock_after_test = all_stock_after[0:-num_obs_after], all_stock_after[-num_obs_after:]
# 做一个变量替换
all_stock_before_train =  all_stock_after_train
all_stock_befire_test = all_stock_after_test




for name, column in all_stock_before_train.iteritems():
    DF_test(column, name=column.name)
    print('\n')

print('1st difference')
#all variable are non-stationary, take 1st difference, then re-run ADF test
all_stock_before_differenced = all_stock_before_train.diff().dropna()
# all_stock_before_differenced = all_stock_before_differenced.diff().dropna()

for name, column in all_stock_before_differenced.iteritems():
    DF_test(column, name=column.name)
    print('\n')
# Out:
# AAPL
# Test statistic: -0.4799194510940182
# P-value: 0.895875871665758
# Number of lags used: 1
# Number of observation used: 492
# Critical values: {'1%': -3.4437112724287253, '5%': -2.8674324209387345, '10%': -2.569908433637385}
#
#
# MSFT
# Test statistic: -0.5984217918568951
# P-value: 0.8713382386234054
# Number of lags used: 9
# Number of observation used: 484
# Critical values: {'1%': -3.4439333076538854, '5%': -2.8675301216074414, '10%': -2.56996050355167}
#
#
# GOOG
# Test statistic: -0.3015933139580943
# P-value: 0.925278367940137
# Number of lags used: 1
# Number of observation used: 492
# Critical values: {'1%': -3.4437112724287253, '5%': -2.8674324209387345, '10%': -2.569908433637385}
#
#
# AMZN
# Test statistic: -2.181328325825993
# P-value: 0.21309185206489045
# Number of lags used: 3
# Number of observation used: 490
# Critical values: {'1%': -3.4437660979098843, '5%': -2.8674565460819896, '10%': -2.569921291128696}
#
#
# TSLA
# Test statistic: -0.714322721260017
# ...

# %%
# Plot for stocks before
fig, axes = plt.subplots(nrows=4, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = all_stock_before_differenced[all_stock_before_differenced.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(all_stock_before.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout()

# %%
# pip install pmdarima
models=[]
import pmdarima as pm
for i, ax in enumerate(axes.flatten()):
    data = all_stock_before_differenced[all_stock_before_differenced.columns[i]]
    print('-'*100)
    print(all_stock_before_differenced.columns[i])
    model =  pm.auto_arima(data,start_p=0,d=1,start_q=0,
          max_p=5,max_d=5,max_q=5, start_P=0,
          D=1, start_Q=0, max_P=5,max_D=5,
          max_Q=5, m=12, seasonal=True,
          error_action='warn',trace=False,
          supress_warnings=True,stepwise=True,
          random_state=20,n_fits=50)
    print(model.summary())
    models.append(model)
# Out:
# ----------------------------------------------------------------------------------------------------
# AAPL
#                                       SARIMAX Results
# ...
# Dep. Variable:                                    y   No. Observations:                  493
# Model:             SARIMAX(5, 1, 0)x(4, 1, [1], 12)   Log Likelihood               -1168.351
# Date:                              Thu, 31 Mar 2022   AIC                           2358.702
# Time:                                      17:12:58   BIC                           2404.614
# Sample:                                           0   HQIC                          2376.749
#                                               - 493
# Covariance Type:                                opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9111      0.043    -21.324      0.000      -0.995      -0.827
# ...

# %%
# Forecast
n_periods = 10
for i in range(8):
    model = models[i]
    models[i].plot_diagnostics()

# %%
n_periods = 10
fig, axes = plt.subplots(nrows=4, ncols=2, dpi=120, figsize=(10,10))
for i, ax in enumerate(axes.flatten()):
    model = models[i]
    df = all_stock_before_test[all_stock_before_test.columns[i]]

    fc, confint = model.predict(n_periods=n_periods, return_conf_int=True)

    index_of_fc = np.arange(n_periods)
    x0 = all_stock_before[all_stock_before.columns[i]][-1]
    y0 = all_stock_before_test[all_stock_before_test.columns[i]]
    y1 = x0+fc_series.cumsum()
    # make series for plotting purpose
    fc_series = pd.Series(fc, index=index_of_fc)
    lower_series = pd.Series(confint[:, 0], index=index_of_fc)
    upper_series = pd.Series(confint[:, 1], index=index_of_fc)
    # Plot
    ax.plot(index_of_fc,y0)
    ax.plot(y1, color='darkgreen')

    ax.fill_between(lower_series.index, 
                     x0+lower_series.cumsum(), 
                     x0+upper_series.cumsum(), 
                     color='k', alpha=.15)

    ax.set_title(all_stock_before_test.columns[i])
    ax.legend(['original','predict','lower and upper'])
    
    test_predict = y1.copy()
    #for x in range(len(test_predict)):
        #test_predict.iloc[x] = pred_list[x]
    eval_result = forecast_accuracy(y1, np.array(y0))
    print('model evaluation result\n', eval_result)
# Out:
# <ipython-input-48-532768efb9ad>:10: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   mins = np.amin(np.hstack([forecast[:, None], actual[:, None]]), axis=1)
# <ipython-input-48-532768efb9ad>:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   maxs = np.amax(np.hstack([forecast[:, None], actual[:, None]]), axis=1)
# <ipython-input-48-532768efb9ad>:10: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   mins = np.amin(np.hstack([forecast[:, None], actual[:, None]]), axis=1)
# ...
