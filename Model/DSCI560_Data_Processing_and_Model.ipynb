# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pylab as plt

# %% [markdown]
# ### Data Processing

# %%
AAPL = pd.read_csv("data/AAPL.csv")
AAPL['Date'] = pd.to_datetime(AAPL['Date'])
AAPL.set_index('Date', inplace = True)
AAPL_before = AAPL.iloc[:252]['Adj Close']
AAPL_after = AAPL.iloc[252:]['Adj Close']
AAPL.iloc[:252]
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-02-01  41.740002  42.244999  41.482498  41.630001  40.362038  130672400
# 2019-02-04  41.852501  42.915001  41.820000  42.812500  41.508522  125982000
# 2019-02-05  43.215000  43.770000  43.087502  43.544998  42.218704  144406400
# 2019-02-06  43.662498  43.892502  43.212502  43.560001  42.233261  112958400
# 2019-02-07  43.099998  43.485001  42.584999  42.735001  41.433388  126966800
# ...               ...        ...        ...        ...        ...        ...
# 2020-01-27  77.514999  77.942497  76.220001  77.237503  76.010155  161940000
# 2020-01-28  78.150002  79.599998  78.047501  79.422501  78.160439  162234000
# 2020-01-29  81.112503  81.962502  80.345001  81.084999  79.796524  216229200
# 2020-01-30  80.135002  81.022499  79.687500  80.967499  79.680878  126743200
# 2020-01-31  80.232498  80.669998  77.072502  77.377502  76.147942  199588400
#
# [252 rows x 6 columns]

# %%
MSFT = pd.read_csv("data/MSFT.csv")
MSFT['Date'] = pd.to_datetime(MSFT['Date'])
MSFT.set_index('Date', inplace = True)
MSFT_before = MSFT.iloc[:252]['Adj Close']
MSFT_after = MSFT.iloc[252:]['Adj Close']
MSFT_after
# Out:
# Date
# 2020-02-03    170.764603
# 2020-02-04    176.385590
# 2020-02-05    176.170135
# 2020-02-06    179.822815
# 2020-02-07    180.077438
#                  ...
# 2022-04-21    280.809998
# 2022-04-22    274.029999
# 2022-04-25    280.720001
# 2022-04-26    270.220001
# 2022-04-27    283.220001
# Name: Adj Close, Length: 564, dtype: float64

# %%
GOOG = pd.read_csv("data/GOOG.csv")
GOOG['Date'] = pd.to_datetime(GOOG['Date'])
GOOG.set_index('Date', inplace = True)
GOOG_before = GOOG.iloc[:252]['Adj Close']
GOOG_after = GOOG.iloc[252:]['Adj Close']
GOOG_after
# Out:
# Date
# 2020-02-03    1485.939941
# 2020-02-04    1447.069946
# 2020-02-05    1448.229980
# 2020-02-06    1476.229980
# 2020-02-07    1479.229980
#                  ...
# 2022-04-21    2498.750000
# 2022-04-22    2392.280029
# 2022-04-25    2465.000000
# 2022-04-26    2390.120117
# 2022-04-27    2300.409912
# Name: Adj Close, Length: 564, dtype: float64

# %%
AMZN = pd.read_csv("data/AMZN.csv")
AMZN['Date'] = pd.to_datetime(AMZN['Date'])
AMZN.set_index('Date', inplace = True)
AMZN_before = AMZN.iloc[:252]['Adj Close']
AMZN_after = AMZN.iloc[252:]['Adj Close']
AMZN_after
# Out:
# Date
# 2020-02-03    2004.199951
# 2020-02-04    2049.669922
# 2020-02-05    2039.869995
# 2020-02-06    2050.229980
# 2020-02-07    2079.280029
#                  ...
# 2022-04-21    2965.919922
# 2022-04-22    2887.000000
# 2022-04-25    2921.479980
# 2022-04-26    2787.820068
# 2022-04-27    2763.340088
# Name: Adj Close, Length: 564, dtype: float64

# %%
TSLA = pd.read_csv("data/TSLA.csv")
TSLA['Date'] = pd.to_datetime(TSLA['Date'])
TSLA.set_index('Date', inplace = True)
TSLA_before = TSLA.iloc[:252]['Adj Close']
TSLA_after = TSLA.iloc[252:]['Adj Close']
TSLA_after
# Out:
# Date
# 2020-02-03     156.000000
# 2020-02-04     177.412003
# 2020-02-05     146.940002
# 2020-02-06     149.792007
# 2020-02-07     149.613998
#                  ...
# 2022-04-21    1008.780029
# 2022-04-22    1005.049988
# 2022-04-25     998.020020
# 2022-04-26     876.419983
# 2022-04-27     881.510010
# Name: Adj Close, Length: 564, dtype: float64

# %%
FB = pd.read_csv("data/FB.csv")
FB['Date'] = pd.to_datetime(FB['Date'])
FB.set_index('Date', inplace = True)
FB_before = FB.iloc[:252]['Adj Close']
FB_after = FB.iloc[252:]['Adj Close']
FB_after
# Out:
# Date
# 2020-02-03    204.190002
# 2020-02-04    209.830002
# 2020-02-05    210.110001
# 2020-02-06    210.850006
# 2020-02-07    212.330002
#                  ...
# 2022-04-21    188.070007
# 2022-04-22    184.110001
# 2022-04-25    186.990005
# 2022-04-26    180.949997
# 2022-04-27    174.949997
# Name: Adj Close, Length: 564, dtype: float64

# %%
NVDA = pd.read_csv("data/NVDA.csv")
NVDA['Date'] = pd.to_datetime(NVDA['Date'])
NVDA.set_index('Date', inplace = True)
NVDA_before = NVDA.iloc[:252]['Adj Close']
NVDA_after = NVDA.iloc[252:]['Adj Close']
NVDA_before
# Out:
# Date
# 2019-02-01    35.944836
# 2019-02-04    37.050037
# 2019-02-05    37.241268
# 2019-02-06    37.998753
# 2019-02-07    36.612926
#                 ...
# 2020-01-27    59.888554
# 2020-01-28    61.825836
# 2020-01-29    61.219963
# 2020-01-30    61.287289
# 2020-01-31    58.948593
# Name: Adj Close, Length: 252, dtype: float64

# %%
INTC = pd.read_csv("data/INTC.csv")
INTC['Date'] = pd.to_datetime(INTC['Date'])
INTC.set_index('Date', inplace = True)
INTC_before = INTC.iloc[:252]['Adj Close']
INTC_after = INTC.iloc[252:]['Adj Close']
INTC_after
# Out:
# Date
# 2020-02-03    60.805191
# 2020-02-04    61.786819
# 2020-02-05    63.561333
# 2020-02-06    63.637211
# 2020-02-07    62.622276
#                 ...
# 2022-04-21    47.500000
# 2022-04-22    46.540001
# 2022-04-25    47.060001
# 2022-04-26    45.520000
# 2022-04-27    45.220001
# Name: Adj Close, Length: 564, dtype: float64

# %% [markdown]
# ### Time Series Analysis - VAR
# https://medium.com/@derejeabera/stock-price-prediction-using-arima-model-251ddb4ee52a
# https://www.machinelearningplus.com/time-series/vector-autoregression-examples-python/

# %%
# from statsmodels.tsa.arima.model import ARIMA
from matplotlib import pyplot

# %%
from statsmodels.tsa.stattools import adfuller
#Dickey-Fuller test for stationariality 
def DF_test(data, name):
    #moving mean and std
    move_m =data.rolling(12).mean()
    move_std = data.rolling(12).std()
#     plt.plot(data, color = 'black', label = 'data_line')
#     plt.plot(move_m, color = 'red', label = 'moving average')
#     plt.plot(move_std, color = 'green', label = 'moving std')
#     plt.title("Mvoing Average & Std")
    
    test_res = adfuller(data, autolag = 'AIC')
    print(name)
    print('Test statistic:', test_res[0])
    print('P-value:', test_res[1])
    print('Number of lags used:', test_res[2])
    print('Number of observation used:', test_res[3])
    print('Critical values:', test_res[4])

# %% [markdown]
# #### Before

# %%
#AAPL_before
# DF_test(AAPL_before)

# %% [markdown]
# #### merge the companies' stocks datatsets together -> then fit the models (Vector Auto Regression (VAR))

# %%
# Import Statsmodels
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic

# %%
#all stock before dataframe merge
all_stock_before = pd.DataFrame()
all_stock_before['AAPL'] = AAPL_before
all_stock_before['MSFT'] = MSFT_before
all_stock_before['GOOG'] = GOOG_before
all_stock_before['AMZN'] = AMZN_before
all_stock_before['TSLA'] = TSLA_before
all_stock_before['FB'] = FB_before
all_stock_before['NVDA'] = NVDA_before
all_stock_before['INTC'] = INTC_before
all_stock_before
# Out:
#                  AAPL        MSFT         GOOG         AMZN        TSLA  \
# Date
# 2019-02-01  40.362038   99.182556  1110.750000  1626.229980   62.442001
# 2019-02-04  41.508522  102.038948  1132.800049  1633.310059   62.577999
# 2019-02-05  42.218704  103.467140  1145.989990  1658.810059   64.269997
# 2019-02-06  42.233261  102.318802  1115.229980  1640.260010   63.444000
# 2019-02-07  41.433388  101.585396  1098.709961  1614.369995   61.501999
# ...               ...         ...          ...          ...         ...
# 2020-01-27  76.010155  158.915451  1433.900024  1828.339966  111.603996
# 2020-01-28  78.160439  162.029541  1452.560059  1853.250000  113.379997
# 2020-01-29  79.796524  164.556015  1458.630005  1858.000000  116.197998
# 2020-01-30  79.680878  169.197784  1455.839966  1870.680054  128.162003
# 2020-01-31  76.147942  166.700623  1434.229980  2008.719971  130.113998
#
#                     FB       NVDA       INTC
# Date
# ...

# %%
# Plot for stocks before
fig, axes = plt.subplots(nrows=4, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = all_stock_before[all_stock_before.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(all_stock_before.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
# Granger’s Causality Test
from statsmodels.tsa.stattools import grangercausalitytests
maxlag=12
test = 'ssr_chi2test'
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

print("Granger’s Causality Test for Stock Data Before the Pandemic:")
grangers_causation_matrix(all_stock_before, variables = all_stock_before.columns)
# Out:
# Granger’s Causality Test for Stock Data Before the Pandemic:
#         AAPL_x  MSFT_x  GOOG_x  AMZN_x  TSLA_x    FB_x  NVDA_x  INTC_x
# AAPL_y  1.0000  0.0012  0.0131  0.0229  0.0193  0.0708  0.1459  0.2561
# MSFT_y  0.0038  1.0000  0.0000  0.0335  0.0026  0.1895  0.0863  0.0000
# GOOG_y  0.0008  0.2327  1.0000  0.4420  0.0034  0.2770  0.0000  0.0005
# AMZN_y  0.2912  0.0405  0.0007  1.0000  0.0769  0.2036  0.2907  0.1542
# TSLA_y  0.0038  0.0002  0.1888  0.0204  1.0000  0.1334  0.0574  0.0079
# FB_y    0.0213  0.0033  0.1117  0.5541  0.0409  1.0000  0.0622  0.1647
# NVDA_y  0.1081  0.0012  0.1181  0.0107  0.1225  0.2246  1.0000  0.1659
# INTC_y  0.1178  0.0319  0.1770  0.0384  0.0036  0.4241  0.0291  1.0000

# %%
# Cointegration Test
from statsmodels.tsa.vector_ar.vecm import coint_johansen

def cointegration_test(df, alpha=0.1): 
    """Perform Johanson's Cointegration Test and Report Summary"""
    out = coint_johansen(df,-1,5)
    d = {'0.9':0, '0.95':1, '0.99':2}
    traces = out.lr1
    cvts = out.cvt[:, d[str(1-alpha)]]
#     print(out.cvt)
    def adjust(val, length= 6): return str(val).ljust(length)

    # Summary
    print('Name   ::  Test Stat > C(90%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

print("Cointegration Test for Stock Data Before the Pandemic:")
cointegration_test(all_stock_before)
# Out:
# Cointegration Test for Stock Data Before the Pandemic:
# Name   ::  Test Stat > C(90%)    =>   Signif
#  ----------------------------------------
# AAPL   ::  166.39    > 137.9954  =>   True
# MSFT   ::  122.72    > 106.7351  =>   True
# GOOG   ::  85.7      > 79.5329   =>   True
# AMZN   ::  57.68     > 56.2839   =>   True
# TSLA   ::  36.9      > 37.0339   =>   False
# FB     ::  21.64     > 21.7781   =>   False
# NVDA   ::  10.96     > 10.4741   =>   True
# INTC   ::  1.03      > 2.9762    =>   False

# %%
#train test split
num_obs = 10 # predict for next 10 days
all_stock_before_train, all_stock_before_test = all_stock_before[0:-num_obs], all_stock_before[-num_obs:]

# Check size
print(all_stock_before_train.shape) 
print(all_stock_before_test.shape)
# Out:
# (242, 8)
# (10, 8)

# %%
# ADF Test on each column to check sataionalities - round 1
for name, column in all_stock_before_train.iteritems():
    DF_test(column, name=column.name)
    print('\n')
# Out:
# AAPL
# Test statistic: 1.3804124687808201
# P-value: 0.9970233166511903
# Number of lags used: 0
# Number of observation used: 241
# Critical values: {'1%': -3.4577787098622674, '5%': -2.873608704758507, '10%': -2.573201765981991}
#
#
# MSFT
# Test statistic: -0.26213268223320746
# P-value: 0.9306988857434648
# Number of lags used: 2
# Number of observation used: 239
# Critical values: {'1%': -3.458010773719797, '5%': -2.8737103617125186, '10%': -2.5732559963936206}
#
#
# GOOG
# Test statistic: 0.37460842289569496
# P-value: 0.9805201487232917
# Number of lags used: 11
# Number of observation used: 230
# Critical values: {'1%': -3.459105583381277, '5%': -2.8741898504150574, '10%': -2.5735117958412097}
#
#
# AMZN
# Test statistic: -2.332998981207091
# P-value: 0.1615458649643502
# Number of lags used: 0
# Number of observation used: 241
# Critical values: {'1%': -3.4577787098622674, '5%': -2.873608704758507, '10%': -2.573201765981991}
#
#
# TSLA
# Test statistic: 1.9931557326936538
# ...

# %%
#all variable are non-stationary, take 1st difference, then re-run ADF test
all_stock_before_differenced = all_stock_before_train.diff().dropna()
# all_stock_before_differenced = all_stock_before_differenced.diff().dropna()

for name, column in all_stock_before_differenced.iteritems():
    DF_test(column, name=column.name)
    print('\n')
# Out:
# AAPL
# Test statistic: -15.964073964147875
# P-value: 7.124598593679932e-29
# Number of lags used: 0
# Number of observation used: 240
# Critical values: {'1%': -3.4578942529658563, '5%': -2.8736593200231484, '10%': -2.573228767361111}
#
#
# MSFT
# Test statistic: -12.858995394695453
# P-value: 5.1584069490487295e-24
# Number of lags used: 1
# Number of observation used: 239
# Critical values: {'1%': -3.458010773719797, '5%': -2.8737103617125186, '10%': -2.5732559963936206}
#
#
# GOOG
# Test statistic: -5.283308429867771
# P-value: 5.928842714152001e-06
# Number of lags used: 10
# Number of observation used: 230
# Critical values: {'1%': -3.459105583381277, '5%': -2.8741898504150574, '10%': -2.5735117958412097}
#
#
# AMZN
# Test statistic: -15.276001881250346
# P-value: 4.64703331137692e-28
# Number of lags used: 0
# Number of observation used: 240
# Critical values: {'1%': -3.4578942529658563, '5%': -2.8736593200231484, '10%': -2.573228767361111}
#
#
# TSLA
# ...

# %% [markdown]
# All p-value < 0.05 after first difference, ready to move on

# %%
#VAR model lag selection and training
model_before = VAR(all_stock_before_differenced)
AIC = []
BIC =  []
FPE = []
HQIC = []
for i in [1,2,3,4,5,6,7,8,9]:
    result = model_before.fit(i)
    AIC.append(result.aic)
    BIC.append(result.bic)
    FPE.append(result.fpe)
    HQIC.append(result.hqic)
#     print('Lag Order =', i)
#     print('AIC : ', result.aic)
#     print('BIC : ', result.bic)
#     print('FPE : ', result.fpe)
#     print('HQIC: ', result.hqic, '\n')
    
x_value = [1,2,3,4,5,6,7,8,9]
plt.plot(x_value, AIC, color = 'black', label = 'aic')
plt.plot(x_value, BIC, color = 'red', label = 'bic')
# plt.plot(FPE, color = 'green', label = 'fpe')
plt.plot(x_value, HQIC, color = 'blue', label = 'hqic')
plt.legend(loc="upper left")
plt.title("Lag Selection for Model with Stock Data Before the Pandemic")
# print("Lag Selection for Model with Stock Data Before the Pandemic: ")
# Out:
# /Users/zhangzixin/opt/anaconda3/envs/python_36/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# Text(0.5, 1.0, 'Lag Selection for Model with Stock Data Before the Pandemic')

# %%
x = model_before.select_order(maxlags=12)
x.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
#use lag 1 as selected model to fit data
model_before_fitted = model_before.fit(1)
model_before_fitted.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 06, Apr, 2022
# Time:                     23:01:14
# --------------------------------------------------------------------
# No. of Equations:         8.00000    BIC:                    12.2008
# Nobs:                     240.000    HQIC:                   11.5773
# Log likelihood:          -3991.15    FPE:                    70041.8
# AIC:                      11.1566    Det(Omega_mle):         52173.8
# --------------------------------------------------------------------
# Results for equation AAPL
# ...
#              coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------
# const           0.166417         0.050497            3.296           0.001
# L1.AAPL        -0.011543         0.092285           -0.125           0.900
# ...

# %%
#check for residuals
from statsmodels.stats.stattools import durbin_watson
out = durbin_watson(model_before_fitted.resid)

for col, val in zip(all_stock_before.columns, out):
    print(col, ':', round(val, 2))
# Out:
# AAPL : 2.02
# MSFT : 2.0
# GOOG : 1.98
# AMZN : 1.97
# TSLA : 2.01
# FB : 2.0
# NVDA : 2.02
# INTC : 1.99

# %%
# Forecasting
# Get the lag order
lag_order_before = model_before_fitted.k_ar
# print(lag_order_before) 

# Input data for forecasting
forecast_before_input = all_stock_before_differenced.values[-lag_order_before:]
forecast_before_input

# Forecast - this is the result in terms of 1st differencing
fc_before = model_before_fitted.forecast(y=forecast_before_input, steps=num_obs)
all_stock_before_forecast = pd.DataFrame(fc_before, index=all_stock_before.index[-num_obs:], columns=all_stock_before.columns + '_1diff')
all_stock_before_forecast
# Out:
#             AAPL_1diff  MSFT_1diff  GOOG_1diff  AMZN_1diff  TSLA_1diff  \
# Date
# 2020-01-17    0.024160    0.074516    2.423114   -2.338716   -0.199301
# 2020-01-21    0.121406    0.267421    1.724702    0.281444    0.137011
# 2020-01-22    0.144674    0.254713    1.255694    0.749556    0.160497
# 2020-01-23    0.149008    0.252770    1.330796    0.990111    0.162183
# 2020-01-24    0.150265    0.252320    1.347332    1.021260    0.164340
# 2020-01-27    0.150484    0.252482    1.349647    1.030616    0.164952
# 2020-01-28    0.150537    0.252470    1.350299    1.032450    0.164964
# 2020-01-29    0.150551    0.252481    1.350749    1.033293    0.164957
# 2020-01-30    0.150553    0.252480    1.350882    1.033435    0.164954
# 2020-01-31    0.150553    0.252481    1.350915    1.033473    0.164953
#
#             FB_1diff  NVDA_1diff  INTC_1diff
# Date
# 2020-01-17 -0.413990   -0.144348   -0.142472
# 2020-01-21  0.215632    0.105211    0.028564
# ...

# %%
#transformation invertion back to original scale
def invert_transformation(df_train, df_forecast, second_diff=False):
    """Revert back the differencing to get the forecast to original scale."""
    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:        
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = df_train[col].iloc[-1] + df_fc[str(col)+'_1diff'].cumsum()
    return df_fc
all_stock_before_results = invert_transformation(all_stock_before_train, all_stock_before_forecast)        
all_stock_before_results
# Out:
#             AAPL_1diff  MSFT_1diff  GOOG_1diff  AMZN_1diff  TSLA_1diff  \
# Date
# 2020-01-17    0.024160    0.074516    2.423114   -2.338716   -0.199301
# 2020-01-21    0.121406    0.267421    1.724702    0.281444    0.137011
# 2020-01-22    0.144674    0.254713    1.255694    0.749556    0.160497
# 2020-01-23    0.149008    0.252770    1.330796    0.990111    0.162183
# 2020-01-24    0.150265    0.252320    1.347332    1.021260    0.164340
# 2020-01-27    0.150484    0.252482    1.349647    1.030616    0.164952
# 2020-01-28    0.150537    0.252470    1.350299    1.032450    0.164964
# 2020-01-29    0.150551    0.252481    1.350749    1.033293    0.164957
# 2020-01-30    0.150553    0.252480    1.350882    1.033435    0.164954
# 2020-01-31    0.150553    0.252481    1.350915    1.033473    0.164953
#
#             FB_1diff  NVDA_1diff  INTC_1diff  AAPL_forecast  MSFT_forecast  \
# Date
# 2020-01-17 -0.413990   -0.144348   -0.142472      77.581831     162.799324
# ...

# %%
#plot for forecast result and actual result
print("Forecast Results vs. Actuals with Stock Data Before the Pandemic:")
fig, axes = plt.subplots(nrows=int(len(all_stock_before.columns)/2), ncols=2, dpi=150, figsize=(10,10))
for i, (col,ax) in enumerate(zip(all_stock_before.columns, axes.flatten())):
    all_stock_before_results[col+'_forecast'].plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    all_stock_before_test[col][-num_obs:].plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();
# Out:
# Forecast Results vs. Actuals with Stock Data Before the Pandemic:

# %%
# evaluation
from statsmodels.tsa.stattools import acf
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'corr':corr, 'minmax':minmax})

res_before = []
name_list = list(all_stock_before.columns)
for name in name_list:
#     print('Forecast Accuracy of: {}'.format(name))
    accuracy_prod = forecast_accuracy(all_stock_before_results[name+'_forecast'].values, all_stock_before_test[name])
#     print(accuracy_prod)
    res_before.append(accuracy_prod)
#     for k, v in accuracy_prod.items():
#         print(k, ': ', round(v,4))
#     print('\n')
print("Evaluation of Model Trained with Stock Data Before the Pandemic:")
res_before = pd.DataFrame.from_dict(res_before, orient='columns')
res_before['Company'] = list(all_stock_before.columns)
res_before = res_before.set_index('Company')
res_before
# Out:
# Evaluation of Model Trained with Stock Data Before the Pandemic:
# /Users/zhangzixin/opt/anaconda3/envs/python_36/lib/python3.6/site-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# /Users/zhangzixin/opt/anaconda3/envs/python_36/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   del sys.path[0]
#              mape         me        mae       mpe       rmse      corr  \
# Company
# AAPL     0.012264   0.115851   0.949590  0.001719   1.278333 -0.044713
# MSFT     0.010962   0.427910   1.789755  0.002851   2.457051  0.487785
# ...

# %% [markdown]
# #### After - VAR

# %%
#all stock before dataframe merge
all_stock_after = pd.DataFrame()
all_stock_after['AAPL'] = AAPL_after
all_stock_after['MSFT'] = MSFT_after
all_stock_after['GOOG'] = GOOG_after
all_stock_after['AMZN'] = AMZN_after
all_stock_after['TSLA'] = TSLA_after
all_stock_after['FB'] = FB_after
all_stock_after['NVDA'] = NVDA_after
all_stock_after['INTC'] = INTC_after
all_stock_after
# Out:
#                   AAPL        MSFT         GOOG         AMZN         TSLA  \
# Date
# 2020-02-03   75.938797  170.764603  1485.939941  2004.199951   156.000000
# 2020-02-04   78.445824  176.385590  1447.069946  2049.669922   177.412003
# 2020-02-05   79.085503  176.170135  1448.229980  2039.869995   146.940002
# 2020-02-06   80.010559  179.822815  1476.229980  2050.229980   149.792007
# 2020-02-07   78.923004  180.077438  1479.229980  2079.280029   149.613998
# ...                ...         ...          ...          ...          ...
# 2022-04-21  166.419998  280.809998  2498.750000  2965.919922  1008.780029
# 2022-04-22  161.789993  274.029999  2392.280029  2887.000000  1005.049988
# 2022-04-25  162.880005  280.720001  2465.000000  2921.479980   998.020020
# 2022-04-26  156.800003  270.220001  2390.120117  2787.820068   876.419983
# 2022-04-27  156.570007  283.220001  2300.409912  2763.340088   881.510010
#
#                     FB        NVDA       INTC
# Date
# ...

# %%
# Plot for stocks after
fig, axes = plt.subplots(nrows=4, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = all_stock_after[all_stock_after.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(all_stock_after.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
# Grangers Causality Test 
print("Granger’s Causality Test for Stock Data During the Pandemic:")
grangers_causation_matrix(all_stock_after, variables = all_stock_after.columns)
# Out:
# Granger’s Causality Test for Stock Data During the Pandemic:
#         AAPL_x  MSFT_x  GOOG_x  AMZN_x  TSLA_x    FB_x  NVDA_x  INTC_x
# AAPL_y  1.0000  0.0001  0.0078  0.2866  0.3448  0.0056  0.0394  0.0001
# MSFT_y  0.0412  1.0000  0.1279  0.0775  0.4663  0.0551  0.1002  0.0002
# GOOG_y  0.2546  0.0580  1.0000  0.3390  0.5148  0.4138  0.0148  0.0083
# AMZN_y  0.4565  0.0058  0.3710  1.0000  0.2414  0.3384  0.3431  0.0311
# TSLA_y  0.0876  0.0832  0.1338  0.1260  1.0000  0.1498  0.0906  0.0140
# FB_y    0.5403  0.0002  0.0103  0.0771  0.2956  1.0000  0.6435  0.0009
# NVDA_y  0.0233  0.0001  0.0156  0.0180  0.1426  0.1491  1.0000  0.0198
# INTC_y  0.1355  0.0427  0.6975  0.3465  0.8601  0.3665  0.4291  1.0000

# %%
# Cointegration Test
print("Cointegration Test for Stock Data During the Pandemic:")
cointegration_test(all_stock_after)
# Out:
# Cointegration Test for Stock Data During the Pandemic:
# Name   ::  Test Stat > C(90%)    =>   Signif
#  ----------------------------------------
# AAPL   ::  164.57    > 137.9954  =>   True
# MSFT   ::  107.26    > 106.7351  =>   True
# GOOG   ::  70.89     > 79.5329   =>   False
# AMZN   ::  46.15     > 56.2839   =>   False
# TSLA   ::  29.58     > 37.0339   =>   False
# FB     ::  15.49     > 21.7781   =>   False
# NVDA   ::  6.43      > 10.4741   =>   False
# INTC   ::  0.57      > 2.9762    =>   False

# %%
#train test split for all_stock_after
num_obs_after = 10 # predict for next 10 days
all_stock_after_train, all_stock_after_test = all_stock_after[0:-num_obs_after], all_stock_after[-num_obs_after:]

# Check size
print(all_stock_after_train.shape) 
print(all_stock_after_test.shape)
# Out:
# (494, 8)
# (10, 8)

# %%
# ADF Test on each column to check sataionalities for all_stock_after - round 1
for name, column in all_stock_after_train.iteritems():
    DF_test(column, name=column.name)
    print('\n')
# Out:
# AAPL
# Test statistic: -0.4799194510940201
# P-value: 0.8958758716657578
# Number of lags used: 1
# Number of observation used: 492
# Critical values: {'1%': -3.4437112724287253, '5%': -2.8674324209387345, '10%': -2.569908433637385}
#
#
# MSFT
# Test statistic: -0.5984217918568974
# P-value: 0.8713382386234051
# Number of lags used: 9
# Number of observation used: 484
# Critical values: {'1%': -3.4439333076538854, '5%': -2.8675301216074414, '10%': -2.56996050355167}
#
#
# GOOG
# Test statistic: -0.30159331395809447
# P-value: 0.925278367940137
# Number of lags used: 1
# Number of observation used: 492
# Critical values: {'1%': -3.4437112724287253, '5%': -2.8674324209387345, '10%': -2.569908433637385}
#
#
# AMZN
# Test statistic: -2.181328325825993
# P-value: 0.21309185206489045
# Number of lags used: 3
# Number of observation used: 490
# Critical values: {'1%': -3.4437660979098843, '5%': -2.8674565460819896, '10%': -2.569921291128696}
#
#
# TSLA
# Test statistic: -0.7143227212600168
# ...

# %%
#all variable are non-stationary, take 1st difference, then re-run ADF test
all_stock_after_differenced = all_stock_after_train.diff().dropna()
# all_stock_after_differenced = all_stock_after_differenced.diff().dropna()

for name, column in all_stock_after_differenced.iteritems():
    DF_test(column, name=column.name)
    print('\n')
# Out:
# AAPL
# Test statistic: -24.624726450117656
# P-value: 0.0
# Number of lags used: 0
# Number of observation used: 492
# Critical values: {'1%': -3.4437112724287253, '5%': -2.8674324209387345, '10%': -2.569908433637385}
#
#
# MSFT
# Test statistic: -6.9380767044002685
# P-value: 1.0421013525136573e-09
# Number of lags used: 8
# Number of observation used: 484
# Critical values: {'1%': -3.4439333076538854, '5%': -2.8675301216074414, '10%': -2.56996050355167}
#
#
# GOOG
# Test statistic: -24.77210070617099
# P-value: 0.0
# Number of lags used: 0
# Number of observation used: 492
# Critical values: {'1%': -3.4437112724287253, '5%': -2.8674324209387345, '10%': -2.569908433637385}
#
#
# AMZN
# Test statistic: -14.287281303384779
# P-value: 1.2934387429112013e-26
# Number of lags used: 2
# Number of observation used: 490
# Critical values: {'1%': -3.4437660979098843, '5%': -2.8674565460819896, '10%': -2.569921291128696}
#
#
# TSLA
# Test statistic: -23.02954294235754
# P-value: 0.0
# ...

# %% [markdown]
# All p-value < 0.05 after 1st differencing, ready to move on.

# %%
#VAR model lag selection and training
model_after = VAR(all_stock_after_differenced)
AIC_after = []
BIC_after =  []
FPE_after = []
HQIC_after = []
for i in [1,2,3,4,5,6,7,8,9]:
    result = model_after.fit(i)
    AIC_after.append(result.aic)
    BIC_after.append(result.bic)
    FPE_after.append(result.fpe)
    HQIC_after.append(result.hqic)



x_value = [1,2,3,4,5,6,7,8,9]
plt.plot(x_value, AIC_after, color = 'black', label = 'aic')
plt.plot(x_value, BIC_after, color = 'red', label = 'bic')
# plt.plot(FPE, color = 'green', label = 'fpe')
plt.plot(x_value, HQIC_after, color = 'blue', label = 'hqic')
plt.legend(loc="upper left")
plt.title("Lag Selection for Model with Stock Data During the Pandemic")

a = model_after.select_order(maxlags=12)
a.summary()
# Out:
# /Users/zhangzixin/opt/anaconda3/envs/python_36/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
#use lag 1 as selected model to fit data
model_after_fitted = model_after.fit(1)
model_after_fitted.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 06, Apr, 2022
# Time:                     23:01:22
# --------------------------------------------------------------------
# No. of Equations:         8.00000    BIC:                    30.2746
# Nobs:                     492.000    HQIC:                   29.9015
# Log likelihood:          -12809.4    FPE:                7.60824e+12
# AIC:                      29.6602    Det(Omega_mle):     6.58118e+12
# --------------------------------------------------------------------
# Results for equation AAPL
# ...
#              coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------
# const           0.183250         0.109552            1.673           0.094
# L1.AAPL        -0.044330         0.071786           -0.618           0.537
# ...

# %%
#check for residuals
from statsmodels.stats.stattools import durbin_watson
out = durbin_watson(model_after_fitted.resid)

for col, val in zip(all_stock_after.columns, out):
    print(col, ':', round(val, 2))
# Out:
# AAPL : 1.98
# MSFT : 1.96
# GOOG : 1.97
# AMZN : 1.98
# TSLA : 1.99
# FB : 1.98
# NVDA : 2.01
# INTC : 1.99

# %%
# Forecasting
# Get the lag order
lag_order_after = model_after_fitted.k_ar
# print(lag_order_before) 

# Input data for forecasting
forecast_after_input = all_stock_after_differenced.values[-lag_order_after:]
forecast_after_input

# Forecast - this is the result in terms of 1st differencing
fc_after = model_after_fitted.forecast(y=forecast_after_input, steps=num_obs_after)
all_stock_after_forecast = pd.DataFrame(fc_after, index=all_stock_after.index[-num_obs_after:], columns=all_stock_after.columns + '_1diff')
all_stock_after_forecast
# Out:
#             AAPL_1diff  MSFT_1diff  GOOG_1diff  AMZN_1diff  TSLA_1diff  \
# Date
# 2022-01-18   -0.181069   -0.667777   -3.588888   -3.823450    4.231734
# 2022-01-19    0.351742    0.604610    4.702783    3.856807    2.177603
# 2022-01-20    0.152938    0.165910    2.231967    1.933905    1.654486
# 2022-01-21    0.204580    0.301556    2.894174    2.597313    1.799226
# 2022-01-24    0.188403    0.259954    2.690108    2.387463    1.768756
# 2022-01-25    0.193608    0.273041    2.755318    2.453408    1.779700
# 2022-01-26    0.191978    0.268924    2.734817    2.432546    1.776060
# 2022-01-27    0.192489    0.270217    2.741259    2.439122    1.777192
# 2022-01-28    0.192329    0.269811    2.739231    2.437054    1.776837
# 2022-01-31    0.192379    0.269939    2.739869    2.437704    1.776949
#
#             FB_1diff  NVDA_1diff  INTC_1diff
# Date
# 2022-01-18 -1.413637   -0.095385   -0.402227
# 2022-01-19  0.500526    0.757732    0.105944
# ...

# %%
#transformation invertion back to original scale
all_stock_after_results = invert_transformation(all_stock_after_train, all_stock_after_forecast)        
all_stock_after_results
# Out:
#             AAPL_1diff  MSFT_1diff  GOOG_1diff  AMZN_1diff  TSLA_1diff  \
# Date
# 2022-01-18   -0.181069   -0.667777   -3.588888   -3.823450    4.231734
# 2022-01-19    0.351742    0.604610    4.702783    3.856807    2.177603
# 2022-01-20    0.152938    0.165910    2.231967    1.933905    1.654486
# 2022-01-21    0.204580    0.301556    2.894174    2.597313    1.799226
# 2022-01-24    0.188403    0.259954    2.690108    2.387463    1.768756
# 2022-01-25    0.193608    0.273041    2.755318    2.453408    1.779700
# 2022-01-26    0.191978    0.268924    2.734817    2.432546    1.776060
# 2022-01-27    0.192489    0.270217    2.741259    2.439122    1.777192
# 2022-01-28    0.192329    0.269811    2.739231    2.437054    1.776837
# 2022-01-31    0.192379    0.269939    2.739869    2.437704    1.776949
#
#             FB_1diff  NVDA_1diff  INTC_1diff  AAPL_forecast  MSFT_forecast  \
# Date
# 2022-01-18 -1.413637   -0.095385   -0.402227     172.668723     308.892160
# ...

# %%
#plot for forecast result and actual result
print("Forecast Results vs. Actuals with Stock Data During the Pandemic:")

fig, axes = plt.subplots(nrows=int(len(all_stock_after.columns)/2), ncols=2, dpi=150, figsize=(10,10))
for i, (col,ax) in enumerate(zip(all_stock_after.columns, axes.flatten())):
    all_stock_after_results[col+'_forecast'].plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    all_stock_after_test[col][-num_obs_after:].plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();
# Out:
# Forecast Results vs. Actuals with Stock Data During the Pandemic:

# %%
# evaluation
from statsmodels.tsa.stattools import acf
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'corr':corr, 'minmax':minmax})

# name_list = list(all_stock_after.columns)
# for name in name_list:
#     print('Forecast Accuracy of: {}'.format(name))
#     accuracy_prod = forecast_accuracy(all_stock_after_results[name+'_forecast'].values, all_stock_after_test[name])
#     for k, v in accuracy_prod.items():
#         print(k, ': ', round(v,4))
#     print('\n')
    
res_after = []
name_list = list(all_stock_after.columns)
for name in name_list:
#     print('Forecast Accuracy of: {}'.format(name))
    accuracy_prod = forecast_accuracy(all_stock_after_results[name+'_forecast'].values, all_stock_after_test[name])
#     print(accuracy_prod)
    res_after.append(accuracy_prod)
#     for k, v in accuracy_prod.items():
#         print(k, ': ', round(v,4))
#     print('\n')
print("Evaluation of Model Trained with Stock Data During the Pandemic:")
res_after = pd.DataFrame.from_dict(res_after, orient='columns')
res_after['Company'] = list(all_stock_after.columns)
res_after = res_after.set_index('Company')
res_after
# Out:
# Evaluation of Model Trained with Stock Data During the Pandemic:
# /Users/zhangzixin/opt/anaconda3/envs/python_36/lib/python3.6/site-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# /Users/zhangzixin/opt/anaconda3/envs/python_36/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   del sys.path[0]
#              mape          me         mae       mpe        rmse      corr  \
# Company
# AAPL     0.055824    9.025680    9.031367  0.055792   10.329025  0.102701
# MSFT     0.035567   10.536128   10.536128  0.035567   12.125435  0.248223
# ...

# %% [markdown]
# ### ARIMA Evaluation

# %% [markdown]
# #### before

# %%
output = pd.DataFrame()
output = output.append({'mape': 0.015730577929001864, 'me': 0.1146488991688102, 'mae': 1.2152944029051724, 'mpe': 0.0017046516071718843, 'rmse': 1.622101175165962, 'corr': -0.016275141951328925, 'minmax': 0.015403638790676744}, ignore_index=True)
output = output.append({'mape': 0.03768740377734239, 'me': 6.1316181124644, 'mae': 6.1316181124644, 'mpe': 0.03768740377734239, 'rmse': 6.565902703614407, 'corr': 0.5089791658329028, 'minma x': 0.03612089730304002}, ignore_index=True)
output = output.append({'mape': 0.027151496409660157, 'me': 13.155815275562418, 'mae': 39.5973092051569, 'mpe': 0.009332945428535614, 'rmse': 44.114282651069644, 'corr': -0.7369927226822063, 'minmax': 0.02646636193991614}, ignore_index=True)
output = output.append({'mape': 0.06008339534276429, 'me': 107.67740313422507, 'mae': 112.17256133635172, 'mpe': 0.05784557311416921, 'rmse': 117.1094413327295, 'corr': 0.0949045348344391, 'minmax': 0.056392688321967754}, ignore_index=True)
output = output.append({'mape': 0.20365211730319518, 'me': 23.0742331811123, 'mae': 23.0742331811123, 'mp e': 0.20365211730319518, 'rmse': 23.562494314627937, 'corr': 0.8799059786133834, 'mi nmax': 0.16757931663932768}, ignore_index=True)
output = output.append({'mape': 0.06604737433351399, 'me': -13.722263711941148, 'mae': 14.489328957268631, 'mpe': -0.06224832906517016, 'rmse': 15.666214884680244, 'corr': -0.7011730373557672, 'minmax': 0.06601196507796059}, ignore_index=True)
output = output.append({'mape': 0.03196536772625051, 'me': 0.06873504177921816, 'mae': 1.952890003409744, 'mpe': 0.0017620325166283744, 'rmse': 2.224383589431767, 'corr': -0.6840596906263579, 'minmax': 0.031147972560291004}, ignore_index=True)
output = output.append({'mape': 0.03587186959115422, 'me': 0.5652676263477382, 'mae': 2.146435445631645, 'mpe': 0.011034450572053673, 'rmse': 2.4986821654560063, 'corr': 0.47791299383801666, 'minmax': 0.03460067439177816}, ignore_index=True)
output
# Out:
#        corr         mae      mape          me    minmax       mpe        rmse  \
# 0 -0.016275    1.215294  0.015731    0.114649  0.015404  0.001705    1.622101
# 1  0.508979    6.131618  0.037687    6.131618       NaN  0.037687    6.565903
# 2 -0.736993   39.597309  0.027151   13.155815  0.026466  0.009333   44.114283
# 3  0.094905  112.172561  0.060083  107.677403  0.056393  0.057846  117.109441
# 4  0.879906   23.074233  0.203652   23.074233       NaN       NaN   23.562494
# 5 -0.701173   14.489329  0.066047  -13.722264  0.066012 -0.062248   15.666215
# 6 -0.684060    1.952890  0.031965    0.068735  0.031148  0.001762    2.224384
# 7  0.477913    2.146435  0.035872    0.565268  0.034601  0.011034    2.498682
#
#     minma x   mi nmax      mp e
# 0       NaN       NaN       NaN
# 1  0.036121       NaN       NaN
# 2       NaN       NaN       NaN
# 3       NaN       NaN       NaN
# 4       NaN  0.167579  0.203652
# 5       NaN       NaN       NaN
# 6       NaN       NaN       NaN
# ...

# %% [markdown]
# #### after

# %%
output = pd.DataFrame()
output = output.append({'mape': 0.05128008147170523, 'me': -4.0244004514568035, 'mae': 4.0244004514568035,'mpe': -0.05128008147170523, 'rmse': 4.368347107665753, 'corr': -0.11879544431244174, 'minmax': 0.05128008147170515}, ignore_index=True)
output = output.append({'mape': 0.019027365645738516, 'me': 1.1166211485431945, 'mae': 3.111060212410152, 'mpe': 0.0071324729499055006, 'rmse': 3.3944434165206814, 'corr': -0.316499132676212, 'minmax': 0.018745933176402496}
, ignore_index=True)
output = output.append({'mape': 0.03263365144397794, 'me': -47.94782461394239, 'mae': 47.94782461394239, 'mpe': -0.03263365144397794, 'rmse': 50.05867257169318, 'corr': 0.8087850559758196, 'minmax': 0.032633651443977896}
, ignore_index=True)
output = output.append({'mape': 0.06842301942180053, 'me': 127.95749473603067, 'mae': 127.95749473603067, 'mpe': 0.06842301942180053, 'rmse': 132.95924574181288, 'corr': 0.6224883618233458, 'minmax': 0.06370497331265068}
, ignore_index=True)
output = output.append({'mape': 0.2197823561641238, 'me': -15.945035431361934, 'mae': 24.905978860955926, 'mpe': -0.13932453832390812, 'rmse': 31.056523784342552, 'corr': 0.3571971886514313, 'minmax': 0.2139924728008935}
, ignore_index=True)
output = output.append({'mape': 0.38406829507948215, 'me': -83.65264496654933, 'mae': 83.65264496654933, 'mpe': -0.38406829507948215, 'rmse': 89.65857809870381, 'corr': -0.1917211564220167, 'minmax': 0.38406829507948215}
, ignore_index=True)
output = output.append({'mape': 0.1943216193334125, 'me': -11.964519388891727, 'mae': 11.964519388891727, 'mpe': -0.1943216193334125, 'rmse': 12.830705538633119, 'corr': 0.07538526449470123, 'minmax': 0.19432161933341252}
, ignore_index=True)
output = output.append({'mape': 0.23784698344847963, 'me': -14.807321281750268, 'mae': 14.83014126164025, 'mpe': -0.23744323397409012, 'rmse': 17.776683860832453, 'corr': -0.84615900355021, 'minmax': 0.23784664297475855}, ignore_index=True)

output
# Out:
#        corr         mae      mape          me    minmax       mpe        rmse
# 0 -0.118795    4.024400  0.051280   -4.024400  0.051280 -0.051280    4.368347
# 1 -0.316499    3.111060  0.019027    1.116621  0.018746  0.007132    3.394443
# 2  0.808785   47.947825  0.032634  -47.947825  0.032634 -0.032634   50.058673
# 3  0.622488  127.957495  0.068423  127.957495  0.063705  0.068423  132.959246
# 4  0.357197   24.905979  0.219782  -15.945035  0.213992 -0.139325   31.056524
# 5 -0.191721   83.652645  0.384068  -83.652645  0.384068 -0.384068   89.658578
# 6  0.075385   11.964519  0.194322  -11.964519  0.194322 -0.194322   12.830706
# 7 -0.846159   14.830141  0.237847  -14.807321  0.237847 -0.237443   17.776684

# %% [markdown]
# ### RNN -> Bidirectional LSTM
# https://www.relataly.com/stock-market-prediction-using-multivariate-time-series-in-python/1815/
#
# general guide: https://medium.com/swlh/a-technical-guide-on-rnn-lstm-gru-for-stock-price-prediction-bce2f7f30346

# %% [markdown]
# ### RNN

# %%
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, GRU, LSTM, Bidirectional,Dropout
from keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import SGD

# %%
num_obs = 20

def MinMaxScale(data,time_steps,for_periods,num_obs):
    '''normalize the data before feeding to RNN/BiLSTM'''
    
    
    # predict for next 20 days, as test
    train, test = data[0:-num_obs].iloc[:,0:1].values, data[-num_obs:].iloc[:,0:1].values
    train_len = len(train)
    test_len = len(test)
#     print(train_len, test_len) # 242 10

    # scale the data
    sc = MinMaxScaler(feature_range=(0,1))
    data_scaled = sc.fit_transform(train)

    # create training data of s samples and t time steps
    X_train = []
    y_train = []
    y_train_stacked = []
    for i in range(time_steps,train_len-1): 
        X_train.append(data_scaled[i-time_steps:i,0])
        y_train.append(data_scaled[i:i+for_periods,0])
    X_train, y_train = np.array(X_train), np.array(y_train)
#     print(y_train)

    # Preparing to create X_test
    X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))
    
    inputs = pd.concat((data[0:-num_obs],data[-num_obs:]),axis=0).values
    inputs = inputs[len(inputs)-len(test) - time_steps:]
    inputs = inputs.reshape(-1,1)
    inputs  = sc.transform(inputs)

    # Preparing X_test
    X_test = []
    for i in range(time_steps,test_len+time_steps-for_periods):
        X_test.append(inputs[i-time_steps:i,0])
        
    X_test = np.array(X_test)
    X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))

    return X_train, y_train , X_test, sc

def rnn_model_function(X_train, y_train, X_test, sc):
    '''
    single layer rnn
    '''
    # create a model
    
    rnn_model = Sequential()
    rnn_model.add(SimpleRNN(32, return_sequences=True))
    rnn_model.add(SimpleRNN(32, return_sequences=True))
#     rnn_model.add(SimpleRNN(32, return_sequences=True))
    rnn_model.add(SimpleRNN(32))
    rnn_model.add(Dense(2)) # The time step of the output: 2

    rnn_model.compile(optimizer='rmsprop', loss='mean_squared_error')

    # fit the RNN model
    rnn_model.fit(X_train, y_train, epochs=100, batch_size=150, verbose=0)

    # Finalizing predictions
    rnn_predictions = rnn_model.predict(X_test)
    rnn_predictions = sc.inverse_transform(rnn_predictions) #reverse the min max scaler

    return rnn_model, rnn_predictions

def actual_pred_plot(data, preds,to_plot):
    '''Plot the actual vs. prediction'''
    actual_pred = pd.DataFrame(columns = ['Adj. Close', 'prediction'])
    actual_pred['Adj. Close'] = data.iloc[-len(preds):,0].to_list()
    actual_pred['prediction'] = preds[:,0]

    m = RootMeanSquaredError()
    m.update_state(np.array(actual_pred['Adj. Close']),np.array(actual_pred['prediction']))
    if to_plot == True:
        return (m.result().numpy(), actual_pred.plot() )
    else:
        return m.result().numpy()

# %%
#AAPL before
AAPL_before = pd.DataFrame().assign(AAPL=all_stock_before['AAPL'])
X_train, y_train, X_test, sc = MinMaxScale(AAPL_before,5,2,num_obs)
best_pred = []
min_RMSE = float('inf')
for i in range(10):
    rnn_model, rnn_predictions = rnn_model_function(X_train, y_train, X_test, sc)
    rmse = actual_pred_plot(AAPL_before,rnn_predictions,False)
    if rmse < min_RMSE:
        min_RMSE = rmse
        best_pred = rnn_predictions
    
actual_pred_plot(AAPL_before,best_pred,True)
# Out:
# (1.2245181, <AxesSubplot:>)

# %%
# rnn_model.save('AAPL_Before_RNN')
# loaded = tf.keras.models.load_model('AAPL_Before_RNN')

# %%
#MSFT before
# MSFT_before = pd.DataFrame().assign(MSFT=all_stock_before['MSFT'])
# MSFT_X_train, MSFT_y_train, MSFT_X_test, MSFT_sc = MinMaxScale(MSFT_before,5,2,num_obs)
# MSFT_rnn_model, MSFT_rnn_predictions = rnn_model_function(MSFT_X_train, MSFT_y_train, MSFT_X_test, MSFT_sc)
# actual_pred_plot(MSFT_before,MSFT_rnn_predictions,True)

MSFT_before = pd.DataFrame().assign(MSFT=all_stock_before['MSFT'])
MSFT_X_train, MSFT_y_train, MSFT_X_test, MSFT_sc = MinMaxScale(MSFT_before,5,2,num_obs)
MSFT_best_pred = []
MSFT_min_RMSE = float('inf')
for i in range(10):
    MSFT_rnn_model, MSFT_rnn_predictions = rnn_model_function(MSFT_X_train, MSFT_y_train, MSFT_X_test, MSFT_sc)
    MSFT_rmse = actual_pred_plot(MSFT_before,MSFT_rnn_predictions,False)
    if MSFT_rmse < MSFT_min_RMSE:
        MSFT_min_RMSE = MSFT_rmse
        MSFT_best_pred = MSFT_rnn_predictions
    
actual_pred_plot(MSFT_before,MSFT_rnn_predictions,True)
# Out:
# (5.2535853, <AxesSubplot:>)

# %%
# MSFT_rnn_model.save('MSFT_Before_RNN')
# loaded = tf.keras.models.load_model('MSFT_Before_RNN')
# MSFT_X_test

# %%
#GOOG before
# GOOG_before = pd.DataFrame().assign(GOOG=all_stock_before['GOOG'])
# GOOG_X_train, GOOG_y_train, GOOG_X_test, GOOG_sc = MinMaxScale(GOOG_before,5,2,num_obs)
# GOOG_rnn_model, GOOG_rnn_predictions = rnn_model_function(GOOG_X_train, GOOG_y_train, GOOG_X_test, GOOG_sc)
# actual_pred_plot(GOOG_before,GOOG_rnn_predictions,num_obs)
GOOG_before = pd.DataFrame().assign(GOOG=all_stock_before['GOOG'])
GOOG_X_train, GOOG_y_train, GOOG_X_test, GOOG_sc = MinMaxScale(GOOG_before,5,2,num_obs)
GOOG_best_pred = []
GOOG_min_RMSE = float('inf')
for i in range(10):
    GOOG_rnn_model, GOOG_rnn_predictions = rnn_model_function(GOOG_X_train, GOOG_y_train, GOOG_X_test, GOOG_sc)
    GOOG_rmse = actual_pred_plot(GOOG_before,GOOG_rnn_predictions,False)
    if GOOG_rmse < GOOG_min_RMSE:
        GOOG_min_RMSE = GOOG_rmse
        GOOG_best_pred = GOOG_rnn_predictions
    
actual_pred_plot(GOOG_before,GOOG_rnn_predictions,True)
# Out:
# (23.124054, <AxesSubplot:>)

# %%
# rnn_model.save_weights('GOOG_Before_RNN')

# %%
#AMZN before
# AMZN_before = pd.DataFrame().assign(AMZN=all_stock_before['AMZN'])
# AMZN_X_train, AMZN_y_train, AMZN_X_test, AMZN_sc = MinMaxScale(AMZN_before,5,2,num_obs)
# AMZN_rnn_model, AMZN_rnn_predictions = rnn_model_function(AMZN_X_train, AMZN_y_train, AMZN_X_test, AMZN_sc)
# actual_pred_plot(AMZN_before,AMZN_rnn_predictions,num_obs)
AMZN_before = pd.DataFrame().assign(AMZN=all_stock_before['AMZN'])
AMZN_X_train, AMZN_y_train, AMZN_X_test, AMZN_sc = MinMaxScale(AMZN_before,5,2,num_obs)
AMZN_best_pred = []
AMZN_min_RMSE = float('inf')
for i in range(10):
    AMZN_rnn_model, AMZN_rnn_predictions = rnn_model_function(AMZN_X_train, AMZN_y_train, AMZN_X_test, AMZN_sc)
    AMZN_rmse = actual_pred_plot(AMZN_before,AMZN_rnn_predictions,False)
    if AMZN_rmse < AMZN_min_RMSE:
        AMZN_min_RMSE = AMZN_rmse
        AMZN_best_pred = AMZN_rnn_predictions
    
actual_pred_plot(AMZN_before,AMZN_rnn_predictions,True)
# Out:
# (56.12564, <AxesSubplot:>)

# %%
# rnn_model.save_weights('AMZN_Before_RNN')

# %%
#TSLA before
# TSLA_before = pd.DataFrame().assign(TSLA=all_stock_before['TSLA'])
# TSLA_X_train, TSLA_y_train, TSLA_X_test, TSLA_sc = MinMaxScale(TSLA_before,5,2,num_obs)
# TSLA_rnn_model, TSLA_rnn_predictions = rnn_model_function(TSLA_X_train, TSLA_y_train, TSLA_X_test, TSLA_sc)
# actual_pred_plot(TSLA_before,TSLA_rnn_predictions,num_obs)
TSLA_before = pd.DataFrame().assign(TSLA=all_stock_before['TSLA'])
TSLA_X_train, TSLA_y_train, TSLA_X_test, TSLA_sc = MinMaxScale(TSLA_before,5,2,num_obs)
TSLA_best_pred = []
TSLA_min_RMSE = float('inf')
for i in range(10):
    TSLA_rnn_model, TSLA_rnn_predictions = rnn_model_function(TSLA_X_train, TSLA_y_train, TSLA_X_test, TSLA_sc)
    TSLA_rmse = actual_pred_plot(TSLA_before,TSLA_rnn_predictions,False)
    if TSLA_rmse < TSLA_min_RMSE:
        TSLA_min_RMSE = TSLA_rmse
        TSLA_best_pred = TSLA_rnn_predictions
    
actual_pred_plot(TSLA_before,TSLA_rnn_predictions,True)
# Out:
# (24.107307, <AxesSubplot:>)

# %%
# rnn_model.save_weights('TSLA_Before_RNN')

# %%
#FB before
# FB_before = pd.DataFrame().assign(FB=all_stock_before['FB'])
# FB_X_train, FB_y_train, FB_X_test, FB_sc = MinMaxScale(FB_before,5,2,num_obs)
# FB_rnn_model, FB_rnn_predictions = rnn_model_function(FB_X_train, FB_y_train, FB_X_test, FB_sc)
# actual_pred_plot(FB_before,FB_rnn_predictions,num_obs)
FB_before = pd.DataFrame().assign(FB=all_stock_before['FB'])
FB_X_train, FB_y_train, FB_X_test, FB_sc = MinMaxScale(FB_before,5,2,num_obs)
FB_best_pred = []
FB_min_RMSE = float('inf')
for i in range(10):
    FB_rnn_model, FB_rnn_predictions = rnn_model_function(FB_X_train, FB_y_train, FB_X_test, FB_sc)
    FB_rmse = actual_pred_plot(FB_before,FB_rnn_predictions,False)
    if FB_rmse < FB_min_RMSE:
        FB_min_RMSE = FB_rmse
        FB_best_pred = FB_rnn_predictions
    
actual_pred_plot(FB_before,FB_rnn_predictions,True)
# Out:
# (10.789324, <AxesSubplot:>)

# %%
# rnn_model.save_weights('FB_Before_RNN')

# %%
#NVDA before
# NVDA_before = pd.DataFrame().assign(NVDA=all_stock_before['NVDA'])
# NVDA_X_train, NVDA_y_train, NVDA_X_test, NVDA_sc = MinMaxScale(NVDA_before,5,2,num_obs)
# NVDA_rnn_model, NVDA_rnn_predictions = rnn_model_function(NVDA_X_train, NVDA_y_train, NVDA_X_test, NVDA_sc)
# actual_pred_plot(NVDA_before,NVDA_rnn_predictions,num_obs)
NVDA_before = pd.DataFrame().assign(NVDA=all_stock_before['NVDA'])
NVDA_X_train, NVDA_y_train, NVDA_X_test, NVDA_sc = MinMaxScale(NVDA_before,5,2,num_obs)
NVDA_best_pred = []
NVDA_min_RMSE = float('inf')
for i in range(10):
    NVDA_rnn_model, NVDA_rnn_predictions = rnn_model_function(NVDA_X_train, NVDA_y_train, NVDA_X_test, NVDA_sc)
    NVDA_rmse = actual_pred_plot(NVDA_before,NVDA_rnn_predictions,False)
    if NVDA_rmse < NVDA_min_RMSE:
        NVDA_min_RMSE = NVDA_rmse
        NVDA_best_pred = NVDA_rnn_predictions
    
actual_pred_plot(NVDA_before,NVDA_rnn_predictions,True)
# Out:
# (6.1579766, <AxesSubplot:>)

# %%
# rnn_model.save_weights('NVDA_Before_RNN')

# %%
#INTC before
# INTC_before = pd.DataFrame().assign(INTC=all_stock_before['INTC'])
# INTC_X_train, INTC_y_train, INTC_X_test, INTC_sc = MinMaxScale(INTC_before,5,2,num_obs)
# INTC_rnn_model, INTC_rnn_predictions = rnn_model_function(INTC_X_train, INTC_y_train, INTC_X_test, INTC_sc)
# actual_pred_plot(INTC_before,INTC_rnn_predictions,num_obs)
INTC_before = pd.DataFrame().assign(INTC=all_stock_before['INTC'])
INTC_X_train, INTC_y_train, INTC_X_test, INTC_sc = MinMaxScale(INTC_before,5,2,num_obs)
INTC_best_pred = []
INTC_min_RMSE = float('inf')
for i in range(10):
    INTC_rnn_model, INTC_rnn_predictions = rnn_model_function(INTC_X_train, INTC_y_train, INTC_X_test, INTC_sc)
    INTC_rmse = actual_pred_plot(INTC_before,INTC_rnn_predictions,False)
    if INTC_rmse < INTC_min_RMSE:
        INTC_min_RMSE = INTC_rmse
        INTC_best_pred = INTC_rnn_predictions
    
actual_pred_plot(INTC_before,INTC_rnn_predictions,True)
# Out:
# (4.635229, <AxesSubplot:>)

# %%
# rnn_model.save_weights('INTC_Before_RNN')

# %%
#all rmse
all_rmse_list = [min_RMSE, MSFT_min_RMSE, GOOG_min_RMSE, AMZN_min_RMSE, TSLA_min_RMSE, FB_min_RMSE, NVDA_min_RMSE, INTC_min_RMSE]
all_rmse = pd.DataFrame().assign(rmse=all_rmse_list)
all_rmse['Company'] = list(all_stock_after.columns)
all_rmse = all_rmse.set_index('Company')
all_rmse
# Out:
#               rmse
# Company
# AAPL      1.224518
# MSFT      3.021362
# GOOG     42.620808
# AMZN     41.268600
# TSLA     14.562511
# FB        5.543680
# NVDA      1.297170
# INTC      2.723048

# %% [markdown]
# #### after

# %%
#all stock after
# def rnn_after_model_selection(name):
#     data_after = pd.DataFrame().assign(name=all_stock_after[name])
#     X_train_after, y_train_after, X_test_after, sc_after = MinMaxScale(data_after,5,2,num_obs)
#     best_pred_after = []
#     min_RMSE_after = float('inf')
#     for i in range(10):
#         rnn_model_after, rnn_predictions_after = rnn_model_function(X_train_after, y_train_after, X_test_after, sc_after)
#         rmse_after = actual_pred_plot(data_after,rnn_predictions_after,False)
#         if rmse_after < min_RMSE_after:
#             min_RMSE_after = rmse_after
#             best_pred_after = rnn_predictions_after
#     print(name)
#     return data_after, best_pred_after

# for n in list(all_stock_before.columns):
#     data_after, best_pred_after = rnn_after_model_selection(n)
#     actual_pred_plot(data_after,best_pred_after,True)

# %%
AAPL_after = pd.DataFrame().assign(AAPL=all_stock_after['AAPL'])
X_train_after, y_train_after, X_test_after, sc_after = MinMaxScale(AAPL_after,5,2,num_obs)
best_pred_after = []
min_RMSE_after = float('inf')
for i in range(10):
    rnn_model_after, rnn_predictions_after = rnn_model_function(X_train_after, y_train_after, X_test_after, sc_after)
    rmse_after = actual_pred_plot(AAPL_after,rnn_predictions_after,False)
    if rmse_after < min_RMSE_after:
        min_RMSE_after = rmse_after
        best_pred_after = rnn_predictions_after
        
actual_pred_plot(AAPL_after,best_pred_after,True)
# Out:
# (5.834896, <AxesSubplot:>)

# %%
min_RMSE_after
# Out:
# 5.834896

# %%
MSFT_after = pd.DataFrame().assign(MSFT=all_stock_after['MSFT'])
MSFT_X_train_after, MSFT_y_train_after, MSFT_X_test_after, MSFT_sc_after = MinMaxScale(MSFT_after,5,2,num_obs)
MSFT_best_pred_after = []
MSFT_min_RMSE_after = float('inf')
for i in range(10):
    MSFT_rnn_model_after, MSFT_rnn_predictions_after = rnn_model_function(MSFT_X_train_after, MSFT_y_train_after, MSFT_X_test_after, MSFT_sc_after)
    MSFT_rmse_after = actual_pred_plot(MSFT_after,MSFT_rnn_predictions_after,False)
    if MSFT_rmse_after < MSFT_min_RMSE_after:
        MSFT_min_RMSE_after = MSFT_rmse_after
        MSFT_best_pred_after = MSFT_rnn_predictions_after
        
actual_pred_plot(MSFT_after,MSFT_best_pred_after,True)
# Out:
# (9.874867, <AxesSubplot:>)

# %%
GOOG_after = pd.DataFrame().assign(GOOG=all_stock_after['GOOG'])
GOOG_X_train_after, GOOG_y_train_after, GOOG_X_test_after, GOOG_sc_after = MinMaxScale(GOOG_after,5,2,num_obs)
GOOG_best_pred_after = []
GOOG_min_RMSE_after = float('inf')
for i in range(10):
    GOOG_rnn_model_after, GOOG_rnn_predictions_after = rnn_model_function(GOOG_X_train_after, GOOG_y_train_after, GOOG_X_test_after, GOOG_sc_after)
    GOOG_rmse_after = actual_pred_plot(GOOG_after,GOOG_rnn_predictions_after,False)
    if GOOG_rmse_after < GOOG_min_RMSE_after:
        GOOG_min_RMSE_after = GOOG_rmse_after
        GOOG_best_pred_after = GOOG_rnn_predictions_after
        
actual_pred_plot(GOOG_after,GOOG_best_pred_after,True)
# Out:
# (82.96732, <AxesSubplot:>)

# %%
AMZN_after = pd.DataFrame().assign(AMZN=all_stock_after['AMZN'])
AMZN_X_train_after, AMZN_y_train_after, AMZN_X_test_after, AMZN_sc_after = MinMaxScale(AMZN_after,5,2,num_obs)
AMZN_best_pred_after = []
AMZN_min_RMSE_after = float('inf')
for i in range(10):
    AMZN_rnn_model_after, AMZN_rnn_predictions_after = rnn_model_function(AMZN_X_train_after, AMZN_y_train_after, AMZN_X_test_after, AMZN_sc_after)
    AMZN_rmse_after = actual_pred_plot(AMZN_after,AMZN_rnn_predictions_after,False)
    if AMZN_rmse_after < AMZN_min_RMSE_after:
        AMZN_min_RMSE_after = AMZN_rmse_after
        AMZN_best_pred_after = AMZN_rnn_predictions_after
        
actual_pred_plot(AMZN_after,AMZN_best_pred_after,True)
# Out:
# (143.44247, <AxesSubplot:>)

# %%
TSLA_after = pd.DataFrame().assign(TSLA=all_stock_after['TSLA'])
TSLA_X_train_after, TSLA_y_train_after, TSLA_X_test_after, TSLA_sc_after = MinMaxScale(TSLA_after,5,2,num_obs)
TSLA_best_pred_after = []
TSLA_min_RMSE_after = float('inf')
for i in range(10):
    TSLA_rnn_model_after, TSLA_rnn_predictions_after = rnn_model_function(TSLA_X_train_after, TSLA_y_train_after, TSLA_X_test_after, TSLA_sc_after)
    TSLA_rmse_after = actual_pred_plot(TSLA_after,TSLA_rnn_predictions_after,False)
    if TSLA_rmse_after < TSLA_min_RMSE_after:
        TSLA_min_RMSE_after = TSLA_rmse_after
        TSLA_best_pred_after = TSLA_rnn_predictions_after
        
actual_pred_plot(TSLA_after,TSLA_best_pred_after,True)
# Out:
# (46.759098, <AxesSubplot:>)

# %%
FB_after = pd.DataFrame().assign(FB=all_stock_after['FB'])
FB_X_train_after, FB_y_train_after, FB_X_test_after, FB_sc_after = MinMaxScale(FB_after,5,2,num_obs)
FB_best_pred_after = []
FB_min_RMSE_after = float('inf')
for i in range(10):
    FB_rnn_model_after, FB_rnn_predictions_after = rnn_model_function(FB_X_train_after, FB_y_train_after, FB_X_test_after, FB_sc_after)
    FB_rmse_after = actual_pred_plot(FB_after,FB_rnn_predictions_after,False)
    if FB_rmse_after < FB_min_RMSE_after:
        FB_min_RMSE_after = FB_rmse_after
        FB_best_pred_after = FB_rnn_predictions_after
        
actual_pred_plot(FB_after,FB_best_pred_after,True)
# Out:
# (9.3182745, <AxesSubplot:>)

# %%
NVDA_after = pd.DataFrame().assign(NVDA=all_stock_after['NVDA'])
NVDA_X_train_after, NVDA_y_train_after, NVDA_X_test_after, NVDA_sc_after = MinMaxScale(NVDA_after,5,2,num_obs)
NVDA_best_pred_after = []
NVDA_min_RMSE_after = float('inf')
for i in range(10):
    NVDA_rnn_model_after, NVDA_rnn_predictions_after = rnn_model_function(NVDA_X_train_after, NVDA_y_train_after, NVDA_X_test_after, NVDA_sc_after)
    NVDA_rmse_after = actual_pred_plot(NVDA_after,NVDA_rnn_predictions_after,False)
    if NVDA_rmse_after < NVDA_min_RMSE_after:
        NVDA_min_RMSE_after = NVDA_rmse_after
        NVDA_best_pred_after = NVDA_rnn_predictions_after
        
actual_pred_plot(NVDA_after,NVDA_best_pred_after,True)
# Out:
# (11.206683, <AxesSubplot:>)

# %%
INTC_after = pd.DataFrame().assign(INTC=all_stock_after['INTC'])
INTC_X_train_after, INTC_y_train_after, INTC_X_test_after, INTC_sc_after = MinMaxScale(INTC_after,5,2,num_obs)
INTC_best_pred_after = []
INTC_min_RMSE_after = float('inf')
for i in range(10):
    INTC_rnn_model_after, INTC_rnn_predictions_after = rnn_model_function(INTC_X_train_after, INTC_y_train_after, INTC_X_test_after, INTC_sc_after)
    INTC_rmse_after = actual_pred_plot(INTC_after,INTC_rnn_predictions_after,False)
    if INTC_rmse_after < INTC_min_RMSE_after:
        INTC_min_RMSE_after = INTC_rmse_after
        INTC_best_pred_after = INTC_rnn_predictions_after
        
actual_pred_plot(INTC_after,INTC_best_pred_after,True)
# Out:
# (1.9710695, <AxesSubplot:>)

# %%
all_rmse_list_after = [min_RMSE_after, MSFT_min_RMSE_after, GOOG_min_RMSE_after, AMZN_min_RMSE_after, TSLA_min_RMSE_after, FB_min_RMSE_after, NVDA_min_RMSE_after, INTC_min_RMSE_after]
all_rmse_after = pd.DataFrame().assign(rmse=all_rmse_list_after)
all_rmse_after
# Out:
#          rmse
# 0    5.834896
# 1    9.874867
# 2   82.967323
# 3  143.442474
# 4   46.759098
# 5    9.318274
# 6   11.206683
# 7    1.971069

# %% [markdown]
# #### LSTM

# %% [markdown]
# #### before

# %%
def LSTM_model(X_train, y_train, X_test, sc):
    
    # The LSTM architecture
    my_LSTM_model = Sequential()
    my_LSTM_model.add(Bidirectional(LSTM(units=128, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh')))
    my_LSTM_model.add(Bidirectional(LSTM(units=64, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh')))

#     my_LSTM_model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
    #my_LSTM_model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
    my_LSTM_model.add(Bidirectional(LSTM(units=64, activation='tanh')))
    my_LSTM_model.add(Dropout(0.2))
    my_LSTM_model.add(Dense(units=2))

    # Compiling
    my_LSTM_model.compile(optimizer='adam',loss='mean_squared_error')
    # Fitting to the training set
    my_LSTM_model.fit(X_train,y_train,epochs=50,batch_size=128, verbose=0)

    LSTM_prediction = my_LSTM_model.predict(X_test)
    LSTM_prediction = sc.inverse_transform(LSTM_prediction)

    return my_LSTM_model, LSTM_prediction

# %%
#APPL_before
AAPL_before = pd.DataFrame().assign(AAPL=all_stock_before['AAPL'])
X_train, y_train, X_test, sc = MinMaxScale(AAPL_before,3,2,num_obs)
best_pred = []
min_RMSE = float('inf')
for i in range(10):
    AAPL_LSTM_model, LSTM_predictions = LSTM_model(X_train, y_train, X_test, sc)
    rmse = actual_pred_plot(AAPL_before,LSTM_predictions,False)
    if rmse < min_RMSE:
        min_RMSE = rmse
        best_pred = LSTM_predictions
    
actual_pred_plot(AAPL_before,best_pred,True)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7faa4f48c8c8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
#MSFT_before
MSFT_before = pd.DataFrame().assign(MSFT=all_stock_before['MSFT'])
X_train, y_train, X_test, sc = MinMaxScale(MSFT_before,3,2,num_obs)
best_pred = []
MSFT_min_RMSE = float('inf')
for i in range(10):
    MSFT_LSTM_model, LSTM_predictions = LSTM_model(X_train, y_train, X_test, sc)
    rmse = actual_pred_plot(MSFT_before,LSTM_predictions,False)
    print(rmse)
    if rmse < MSFT_min_RMSE:
        MSFT_min_RMSE = rmse
        best_pred = LSTM_predictions
        print(best_pred)
    
actual_pred_plot(MSFT_before,best_pred,True)
# Out:
# 3.1003847
# [[157.98306 157.82922]
#  [158.4082  158.24565]
#  [158.88191 158.70897]
#  [157.7584  157.60214]
#  [158.27907 158.11829]
#  [159.4399  159.2677 ]
#  [160.8736  160.67657]
#  [162.05426 161.84018]
#  [162.09573 161.88063]
#  [162.77066 162.54453]
#  [163.85582 163.62001]
#  [165.76004 165.49672]
#  [167.02974 166.74287]
#  [166.84962 166.56284]
#  [166.69182 166.4096 ]
#  [166.15858 165.88295]
#  [164.86217 164.59988]
#  [164.34027 164.09225]]
# 2.940579
# [[156.38065 156.8707 ]
#  [156.76308 157.25632]
#  [157.19144 157.6861 ]
#  [156.1194  156.60855]
#  [156.64319 157.13455]
#  [157.79237 158.29103]
#  [159.12827 159.63504]
#  [160.258   160.77089]
#  [160.29164 160.80547]
#  [160.92792 161.44492]
#  [162.01036 162.5344 ]
#  [163.82388 164.36009]
#  [164.99254 165.53607]
#  [164.80179 165.34375]
#  [164.67047 165.21147]
#  [164.15161 164.68967]
#  [162.87413 163.40347]
#  [162.43292 162.95892]]
# 2.8876772
# [[156.57607 156.70572]
#  [156.98169 157.1178 ]
# ...

# %%
best_pred
# Out:
# []

# %%
#GOOG_before
GOOG_before = pd.DataFrame().assign(GOOG=all_stock_before['GOOG'])
X_train, y_train, X_test, sc = MinMaxScale(GOOG_before,3,2,num_obs)
best_pred = []
GOOG_min_RMSE = float('inf')
for i in range(10):
    GOOG_LSTM_model, LSTM_predictions = LSTM_model(X_train, y_train, X_test, sc)
    rmse = actual_pred_plot(GOOG_before,LSTM_predictions,False)
    if rmse < GOOG_min_RMSE:
        GOOG_min_RMSE = rmse
        best_pred = LSTM_predictions
    
actual_pred_plot(GOOG_before,best_pred,True)
# Out:
# (35.176834, <AxesSubplot:>)

# %%
#AMZN_before
AMZN_before = pd.DataFrame().assign(AMZN=all_stock_before['AMZN'])
X_train, y_train, X_test, sc = MinMaxScale(AMZN_before,3,2,num_obs)
best_pred = []
AMZN_min_RMSEmin_RMSE = float('inf')
for i in range(10):
    AMZN_LSTM_model, LSTM_predictions = LSTM_model(X_train, y_train, X_test, sc)
    rmse = actual_pred_plot(AMZN_before,LSTM_predictions,False)
    if rmse < AMZN_min_RMSEmin_RMSE:
        AMZN_min_RMSE = rmse
        best_pred = LSTM_predictions
    
actual_pred_plot(AMZN_before,best_pred,True)
# Out:
# (45.47642, <AxesSubplot:>)

# %%
#TSLA_before
TSLA_before = pd.DataFrame().assign(TSLA=all_stock_before['TSLA'])
X_train, y_train, X_test, sc = MinMaxScale(TSLA_before,3,2,num_obs)
best_pred = []
TSLA_min_RMSE = float('inf')
for i in range(10):
    TSLA_LSTM_model, LSTM_predictions = LSTM_model(X_train, y_train, X_test, sc)
    rmse = actual_pred_plot(TSLA_before,LSTM_predictions,False)
    if rmse < TSLA_min_RMSE:
        TSLA_min_RMSE = rmse
        best_pred = LSTM_predictions
    
actual_pred_plot(TSLA_before,best_pred,True)
# Out:
# (5.5252547, <AxesSubplot:>)

# %%
#FB_before
FB_before = pd.DataFrame().assign(FB=all_stock_before['FB'])
X_train, y_train, X_test, sc = MinMaxScale(FB_before,3,2,num_obs)
best_pred = []
FB_min_RMSEmin_RMSE = float('inf')
for i in range(10):
    FB_LSTM_model, LSTM_predictions = LSTM_model(X_train, y_train, X_test, sc)
    rmse = actual_pred_plot(FB_before,LSTM_predictions,False)
    if rmse < FB_min_RMSEmin_RMSE:
        FB_min_RMSE = rmse
        best_pred = LSTM_predictions
    
actual_pred_plot(FB_before,best_pred,True)
# Out:
# (6.2869062, <AxesSubplot:>)

# %%
#NVDA_before
NVDA_before = pd.DataFrame().assign(NVDA=all_stock_before['NVDA'])
X_train, y_train, X_test, sc = MinMaxScale(NVDA_before,3,2,num_obs)
best_pred = []
NVDA_min_RMSE = float('inf')
for i in range(10):
    NVDA_LSTM_model, LSTM_predictions = LSTM_model(X_train, y_train, X_test, sc)
    rmse = actual_pred_plot(NVDA_before,LSTM_predictions,False)
    if rmse < NVDA_min_RMSE:
        NVDA_min_RMSE = rmse
        best_pred = LSTM_predictions
    
actual_pred_plot(NVDA_before,best_pred,True)
# Out:
# (1.4597807, <AxesSubplot:>)

# %%
#INTC_before
INTC_before = pd.DataFrame().assign(INTC=all_stock_before['INTC'])
X_train, y_train, X_test, sc = MinMaxScale(INTC_before,3,2,num_obs)
best_pred = []
INTC_min_RMSE = float('inf')
for i in range(10):
    INTC_LSTM_model, LSTM_predictions = LSTM_model(X_train, y_train, X_test, sc)
    rmse = actual_pred_plot(INTC_before,LSTM_predictions,False)
    if rmse < INTC_min_RMSE:
        INTC_min_RMSE = rmse
        best_pred = LSTM_predictions
    
actual_pred_plot(INTC_before,best_pred,True)
# Out:
# (2.723412, <AxesSubplot:>)

# %%
all_rmse_list = [min_RMSE, MSFT_min_RMSE, GOOG_min_RMSE, AMZN_min_RMSE, TSLA_min_RMSE, FB_min_RMSE, NVDA_min_RMSE, INTC_min_RMSE]
all_rmse = pd.DataFrame().assign(rmse=all_rmse_list)
all_rmse['Company'] = list(all_stock_after.columns)
all_rmse = all_rmse.set_index('Company')
all_rmse
# Out:
#               rmse
# Company
# AAPL      1.499559
# MSFT      2.863983
# GOOG     35.176834
# AMZN     45.476421
# TSLA      5.525255
# FB        6.286906
# NVDA      1.459781
# INTC      2.723412

# %%
AAPL_after = pd.DataFrame().assign(AAPL=all_stock_after['AAPL'])
AAPL_X_train_after, AAPL_y_train_after, AAPL_X_test_after, AAPL_sc_after = MinMaxScale(AAPL_after,5,2,num_obs)
AAPL_best_pred_after = []
AAPL_min_RMSE_after = float('inf')
for i in range(10):
    AAPL_lstm_model_after, AAPL_lstm_predictions_after = LSTM_model(AAPL_X_train_after, AAPL_y_train_after, AAPL_X_test_after, AAPL_sc_after)
    AAPL_rmse_after = actual_pred_plot(AAPL_after,AAPL_lstm_predictions_after,False)
    if AAPL_rmse_after < AAPL_min_RMSE_after:
        AAPL_min_RMSE_after = AAPL_rmse_after
        AAPL_best_pred_after = AAPL_lstm_predictions_after
        
actual_pred_plot(AAPL_after,AAPL_best_pred_after,True)
# Out:
# (3.919083, <AxesSubplot:>)

# %%
MSFT_after = pd.DataFrame().assign(MSFT=all_stock_after['MSFT'])
MSFT_X_train_after, MSFT_y_train_after, MSFT_X_test_after, MSFT_sc_after = MinMaxScale(MSFT_after,5,2,num_obs)
MSFT_best_pred_after = []
MSFT_min_RMSE_after = float('inf')
for i in range(10):
    MSFT_lstm_model_after, MSFT_lstm_predictions_after = LSTM_model(MSFT_X_train_after, MSFT_y_train_after, MSFT_X_test_after, MSFT_sc_after)
    MSFT_rmse_after = actual_pred_plot(MSFT_after,MSFT_lstm_predictions_after,False)
    if MSFT_rmse_after < MSFT_min_RMSE_after:
        MSFT_min_RMSE_after = MSFT_rmse_after
        MSFT_best_pred_after = MSFT_lstm_predictions_after
        
actual_pred_plot(MSFT_after,MSFT_best_pred_after,True)
# Out:
# (10.053275, <AxesSubplot:>)

# %%
GOOG_after = pd.DataFrame().assign(GOOG=all_stock_after['GOOG'])
GOOG_X_train_after, GOOG_y_train_after, GOOG_X_test_after, GOOG_sc_after = MinMaxScale(GOOG_after,5,2,num_obs)
GOOG_best_pred_after = []
GOOG_min_RMSE_after = float('inf')
for i in range(10):
    GOOG_lstm_model_after, GOOG_lstm_predictions_after = LSTM_model(GOOG_X_train_after, GOOG_y_train_after, GOOG_X_test_after, GOOG_sc_after)
    GOOG_rmse_after = actual_pred_plot(GOOG_after,GOOG_lstm_predictions_after,False)
    if GOOG_rmse_after < GOOG_min_RMSE_after:
        GOOG_min_RMSE_after = GOOG_rmse_after
        GOOG_best_pred_after = GOOG_lstm_predictions_after
        
actual_pred_plot(GOOG_after,GOOG_best_pred_after,True)
# Out:
# (108.68107, <AxesSubplot:>)

# %%
AMZN_after = pd.DataFrame().assign(AMZN=all_stock_after['AMZN'])
AMZN_X_train_after, AMZN_y_train_after, AMZN_X_test_after, AMZN_sc_after = MinMaxScale(AMZN_after,5,2,num_obs)
AMZN_best_pred_after = []
AMZN_min_RMSE_after = float('inf')
for i in range(10):
    AMZN_lstm_model_after, AMZN_lstm_predictions_after = LSTM_model(AMZN_X_train_after, AMZN_y_train_after, AMZN_X_test_after, AMZN_sc_after)
    AMZN_rmse_after = actual_pred_plot(AMZN_after,AMZN_lstm_predictions_after,False)
    if AMZN_rmse_after < AMZN_min_RMSE_after:
        AMZN_min_RMSE_after = AMZN_rmse_after
        AMZN_best_pred_after = AMZN_lstm_predictions_after
        
actual_pred_plot(AMZN_after,AMZN_best_pred_after,True)
# Out:
# (143.00896, <AxesSubplot:>)

# %%
TSLA_after = pd.DataFrame().assign(TSLA=all_stock_after['TSLA'])
TSLA_X_train_after, TSLA_y_train_after, TSLA_X_test_after, TSLA_sc_after = MinMaxScale(TSLA_after,5,2,num_obs)
TSLA_best_pred_after = []
TSLA_min_RMSE_after = float('inf')
for i in range(2):
    TSLA_lstm_model_after, TSLA_lstm_predictions_after = LSTM_model(TSLA_X_train_after, TSLA_y_train_after, TSLA_X_test_after, TSLA_sc_after)
    TSLA_rmse_after = actual_pred_plot(TSLA_after,TSLA_lstm_predictions_after,False)
    if TSLA_rmse_after < TSLA_min_RMSE_after:
        TSLA_min_RMSE_after = TSLA_rmse_after
        TSLA_best_pred_after = TSLA_lstm_predictions_after
        
actual_pred_plot(TSLA_after,TSLA_best_pred_after,True)
# Out:
# (55.235477, <AxesSubplot:>)

# %%
FB_after = pd.DataFrame().assign(FB=all_stock_after['FB'])
FB_X_train_after, FB_y_train_after, FB_X_test_after, FB_sc_after = MinMaxScale(FB_after,5,2,num_obs)
FB_best_pred_after = []
FB_min_RMSE_after = float('inf')
for i in range(2):
    FB_lstm_model_after, FB_lstm_predictions_after = LSTM_model(FB_X_train_after, FB_y_train_after, FB_X_test_after, FB_sc_after)
    FB_rmse_after = actual_pred_plot(FB_after,FB_lstm_predictions_after,False)
    if FB_rmse_after < FB_min_RMSE_after:
        FB_min_RMSE_after = FB_rmse_after
        FB_best_pred_after = FB_lstm_predictions_after
        
actual_pred_plot(FB_after,FB_best_pred_after,True)
# Out:
# (15.482708, <AxesSubplot:>)

# %%
NVDA_after = pd.DataFrame().assign(NVDA=all_stock_after['NVDA'])
NVDA_X_train_after, NVDA_y_train_after, NVDA_X_test_after, NVDA_sc_after = MinMaxScale(NVDA_after,5,2,num_obs)
NVDA_best_pred_after = []
NVDA_min_RMSE_after = float('inf')
for i in range(2):
    NVDA_lstm_model_after, NVDA_lstm_predictions_after = LSTM_model(NVDA_X_train_after, NVDA_y_train_after, NVDA_X_test_after, NVDA_sc_after)
    NVDA_rmse_after = actual_pred_plot(NVDA_after,NVDA_lstm_predictions_after,False)
    if NVDA_rmse_after < NVDA_min_RMSE_after:
        NVDA_min_RMSE_after = NVDA_rmse_after
        NVDA_best_pred_after = NVDA_lstm_predictions_after
        
actual_pred_plot(NVDA_after,NVDA_best_pred_after,True)
# Out:
# (23.665358, <AxesSubplot:>)

# %%
INTC_after = pd.DataFrame().assign(INTC=all_stock_after['INTC'])
INTC_X_train_after, INTC_y_train_after, INTC_X_test_after, INTC_sc_after = MinMaxScale(INTC_after,5,2,num_obs)
INTC_best_pred_after = []
INTC_min_RMSE_after = float('inf')
for i in range(10):
    INTC_lstm_model_after, INTC_lstm_predictions_after = LSTM_model(INTC_X_train_after, INTC_y_train_after, INTC_X_test_after, INTC_sc_after)
    INTC_rmse_after = actual_pred_plot(INTC_after,INTC_lstm_predictions_after,False)
    if INTC_rmse_after < INTC_min_RMSE_after:
        INTC_min_RMSE_after = INTC_rmse_after
        INTC_best_pred_after = INTC_lstm_predictions_after
        
actual_pred_plot(INTC_after,INTC_best_pred_after,True)
# Out:
# (1.463713, <AxesSubplot:>)

# %%
all_rmse_list_after = [AAPL_min_RMSE_after, MSFT_min_RMSE_after, GOOG_min_RMSE_after, AMZN_min_RMSE_after, TSLA_min_RMSE_after, FB_min_RMSE_after, NVDA_min_RMSE_after, INTC_min_RMSE_after]
all_rmse_after = pd.DataFrame().assign(rmse=all_rmse_list_after)
all_rmse_after
# Out:
#          rmse
# 0    3.919083
# 1   10.053275
# 2  108.681068
# 3  143.008957
# 4   55.235477
# 5   15.482708
# 6   23.665358
# 7    1.463713
